# %% [markdown]
# # Gensim Word2Vec Tutorial professor Leonardo

# %% [markdown]
# <img src="https://images.freeimages.com/images/large-previews/2b9/letters-1-yes-1188348.jpg" alt="drawing" width="350"/>

# %% [markdown]
# # Vamos a implementar um modelo word2vector passo a passo

# %% [markdown]
# #  Word2Vec:
#
# <img src="http://mccormickml.com/assets/word2vec/skip_gram_net_arch.png" alt="drawing" width="550"/>
#
# [[1]](#References:)
#
#
# ## proposta do exercicio:
# Como eu disse antes, este tutorial foca no uso correto do pacote Word2Vec da libray Gensim; portanto, não vou explicar os conceitos e idéias por trás do Word2Vec aqui..
#
# ## breve explicação :
#
# O Word2Vec foi apresentado em dois [artigos] (# Material-for-mais-em-deeps-enting :) entre setembro e outubro de 2013, por uma equipe de pesquisadores do Google. Junto com os artigos, os pesquisadores publicaram sua implementação em C. A implementação do Python foi feita logo após o primeiro artigo, por [Gensim] (https://radimrehurek.com/gensim/index.html).
#
# A suposição subjacente do Word2Vec é que duas palavras que compartilham contextos semelhantes também compartilham um significado semelhante e, conseqüentemente, uma representação vetorial semelhante do modelo. Por exemplo: "cachorro", "filhote" e "filhote" são frequentemente usados ​​em situações semelhantes, com palavras próximas como "bom", "fofo" ou "fofo" e, de acordo com o Word2Vec, eles compartilharão uma representação vetorial semelhante . <br>
#
# Partindo dessa suposição, o Word2Vec pode ser usado para descobrir as relações entre as palavras em um conjunto de dados, calcular a similaridade entre elas ou usar a representação vetorial dessas palavras como entrada para outras aplicações, como classificação de texto ou agrupamento.
#
# # Getting Started
#
# ## Setting up the environment:
#
# `python==3.6.3`
#
# Libraries used:
#  * `xlrd==1.1.0`: https://pypi.org/project/xlrd/
#  * `spaCy==2.0.12`: https://spacy.io/usage/
#  * `gensim==3.4.0`: https://radimrehurek.com/gensim/install.html
#  * `scikit-learn==0.19.1`: http://scikit-learn.org/stable/install.html
#  * `seaborn==0.8`: https://seaborn.pydata.org/installing.html

# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/44/Logo_The_Simpsons.svg" alt="drawing" width="400"/>
#
# ## Os dados:
# Se escolheu brincar com o roteiro dos Simpsons, tanto porque amo os Simpsons quanto porque com mais de 150 mil linhas de diálogos, o conjunto de dados era substancial!
#
# Este conjunto de dados contém os personagens, locais, detalhes do episódio e linhas do roteiro para aproximadamente 600 episódios dos Simpsons, que datam de 1989. Ele pode ser encontrado aqui: https://www.kaggle.com/ambarish/fun-in-text-mining-with-simpsons/data (~25MB)

# %% [markdown]
# # Pré-processando
#
# Mantemos apenas duas colunas:
# * `raw_character_text`: o personagem que fala (pode ser útil ao monitorar as etapas de pré-processamento)
# * `speak_words`: o texto bruto da linha de diálogo
#
# Não mantemos `normalized_text` porque queremos fazer nosso próprio pré-processamento.
#
# Você pode encontrar o arquivo resultante aqui: https://www.kaggle.com/pierremegret/dialogue-lines-of-the-simpsons

# %%
df = pd.read_csv('simpsons_dataset.csv')
df.shape
# Out:
# (158314, 2)

# %%
df.head()
# Out:
#         raw_character_text                                       spoken_words
# 0              Miss Hoover  No, actually, it was a little of both. Sometim...
# 1             Lisa Simpson                             Where's Mr. Bergstrom?
# 2              Miss Hoover  I don't know. Although I'd sure like to talk t...
# 3             Lisa Simpson                         That life is worth living.
# 4  Edna Krabappel-Flanders  The polls will be open from now until the end ...

# %% [markdown]
# Os valores ausentes vêm da parte do script onde algo acontece, mas sem diálogo. Por exemplo "(Springfield Elementary School: EXT. ELEMENTARY - SCHOOL PLAYGROUND - AFTERNOON)"

# %%
df.isnull().sum()
# Out:
# raw_character_text    17814
# spoken_words          26459
# dtype: int64

# %% [markdown]
# Removing the missing values:

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# INFO - 15:08:54: NumExpr defaulting to 2 threads.
# raw_character_text    0
# spoken_words          0
# dtype: int64

# %% [markdown]
# ## Limpeza:
# Estamos lematizando e removendo as palavras irrelevantes e os caracteres não alfabéticos de cada linha do diálogo.

# %%
nlp = spacy.load('en', disable=['ner', 'parser']) # disabling Named Entity Recognition for speed

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

# %% [markdown]
# Remove caracteres não alfabéticos:

# %%
#retira caracteres não alfabéticos e colocar em letras minusculas
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['spoken_words'])

# %% [markdown]
# Aproveitando o atributo spaCy .pipe () para acelerar o processo de limpeza:

# %%
#pipeline é utilizado para paralelizar processamento
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 1.08 mins

# %% [markdown]
# Coloque os resultados em um DataFrame para remover valores ausentes e duplicatas:

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (85964, 1)

# %% [markdown]
# ## Bigrams:
# Estamos usando o pacote Gensim Phrases para detectar automaticamente frases comuns (bigramas) de uma lista de frases.
# https://radimrehurek.com/gensim/models/phrases.html
#
# A principal razão de fazermos isso é pegar palavras como "mr_burns" ou "bart_simpson"!

# %%
from gensim.models.phrases import Phrases, Phraser
# Out:
# INFO - 15:12:00: 'pattern' package not found; tag filters are not available for English

# %% [markdown]
# As `Phrases()` takes a list of list of words as input:

# %%
sent = [row.split() for row in df_clean['clean']]
sent
# Out:
# [['actually',
#   'little',
#   'disease',
#   'magazine',
#   'news',
#   'show',
#   'natural',
#   'think'],
#  ['know', 'sure', 'like', 'talk', 'touch', 'lesson', 'plan', 'teach'],
#  ['life', 'worth', 'live'],
#  ['poll',
#   'open',
#   'end',
#   'recess',
#   'case',
#   'decide',
#   'thought',
#   'final',
#   'statement',
#   'martin'],
#  ['victory', 'party', 'slide'],
#  ['mr', 'bergstrom', 'mr', 'bergstrom'],
#  ['hey',
#   'hey',
#   'move',
#   'morning',
#   'new',
#   'job',
#   'take',
#   'copernicus',
#   'costume'],
#  ['think', 'take', 'train', 'capital', 'city'],
#  ['train', 'like', 'traditional', 'environmentally', 'sound'],
#  ['yes',
#   'backbone',
#   'country',
#   'leland',
#   'stanford',
#   'drive',
#   'golden',
#   'spike',
#   'promontory',
#   'point'],
#  ['hey', 'thank', 'vote', 'man'],
#  ['vote', 'voting', 'geek'],
#  ['get', 'right', 'thank', 'vote', 'girl'],
#  ['sweat', 'long', 'couple', 'people', 'right', 'milhouse'],
#  ['martin', 'martin', 'like', 'recount'],
#  ['want', 'sure', 'martin', 'martin'],
#  ['way', 'mister', 'president'],
#  ['board',
#   'track',
#   'afternoon',
#   'delight',
#   'come',
#   'shelbyville',
#   'parkville'],
#  ['mr', 'bergstrom', 'hey', 'mr', 'bergstrom'],
#  ['oh', 'mean', 'go', 'leave', 'like'],
#  ['ah',
#   'sorry',
#   'lisa',
#   'know',
#   'life',
#   'substitute',
#   'teacher',
#   'fraud',
#   'today',
#   'wear',
#   'gym',
#   'short',
#   'tomorrow',
#   'speak',
#   'french',
#   'pretend',
#   'know',
#   'run',
#   'band',
#   'saw',
#   'god',
#   'know'],
#  ['ah', 'true', 'teacher', 'come'],
#  ['lie', 'good', 'know', 'need', 'project', 'capital', 'city'],
#  ['problem', 'middle', 'class', 'anybody', 'care', 'abandon', 'need'],
#  ['understand', 'mr', 'bergstrom', 'go', 'miss'],
#  ['feel', 'like', 'rely', 'need', 'know'],
#  ['thank', 'mr', 'bergstrom'],
#  ['guess', 'mind', 'run', 'alongside', 'train', 'speed', 'life'],
#  ['goodbye', 'lisa', 'honey', 'okay', 'read', 'note'],
#  ['throw', 'party', 'big', 'bash', 'champagne', 'musician', 'holy', 'man'],
#  ['bart',
#   'vote',
#   'oh',
#   'bad',
#   'thing',
#   'happen',
#   'alright',
#   'allright',
#   'spill',
#   'milk',
#   'spill',
#   'milk',
#   'spill',
#   'milk',
#   'mopey'],
#  ['lisa', 'tell', 'father'],
#  ['mr', 'bergstrom', 'leave', 'today'],
#  ['hey', 'care', 'mean', 'understand'],
#  ['glad', 'cry', 'hate', 'think', 'base', 'emotion', 'sir', 'baboon'],
#  ['yes', 'baboon', 'baboon', 'baboon', 'baboon'],
#  ['think', 'realize', 'say'],
#  ['whoa', 'somebody', 'bind', 'day', 'believe'],
#  ['hear', 'marge', 'call', 'baboon', 'stupid', 'ugliest', 'smelliest', 'ape'],
#  ['homer',
#   'allow',
#   'hurt',
#   'feeling',
#   'right',
#   'little',
#   'girl',
#   'upstairs',
#   'need',
#   'confidence',
#   'father',
#   'shake',
#   'little',
#   'girl',
#   'happy',
#   'faith',
#   'daddy'],
#  ['lisa', 'hold', 'tell', 'cry', 'call', 'daddy', 'baboon'],
#  ['look', 'want', 'forgive'],
#  ['maybe',
#   'help',
#   'lose',
#   'special',
#   'hurt',
#   'lucky',
#   'lose',
#   'special',
#   'special',
#   'roof'],
#  ['child', 'time', 'bed'],
#  ['true',
#   'lot',
#   'special',
#   'people',
#   'life',
#   'lisa',
#   'probably',
#   'place',
#   'food',
#   'real',
#   'good',
#   'guy',
#   'like',
#   'serve',
#   'drink',
#   'oh',
#   'maybe',
#   'explain',
#   'fix',
#   'doll',
#   'house',
#   'good',
#   'monkey',
#   'work',
#   'know',
#   'monkey',
#   'know',
#   'mean'],
#  ['hold', 'nail', 'place', 'tail'],
#  ['sorry', 'call', 'baboon', 'dad'],
#  ['hey', 'matter', 'son'],
#  ['ah', 'dad', 'milhouse', 'lewis', 'vote'],
#  ['hey', 'son', 'get', 'money', 'class', 'president'],
#  ['martin',
#   'guy',
#   'go',
#   'neat',
#   'like',
#   'throw',
#   'ball',
#   'world',
#   'series',
#   'huh'],
#  ['let', 'baby', 'bottle', 'huh', 'motto'],
#  ['hey', 'thanks', 'monkey', 'man'],
#  ['holy', 'moly', 'talk', 'parent'],
#  ['sleep', 'maggie', 'ah'],
#  ['marge', 'let', 'bed', 'big', 'roll', 'life'],
#  ['mmm', 'hor', 'doover'],
#  ['promise', 'eat', 'lie'],
#  ['homer', 'throw', 'party', 'go', 'to', 'pay', 'friend', 'invite', 'home'],
#  ['mom', 'want', 'hear', 'witty', 'banter', 'sophisticated', 'adult'],
#  ['yeah', 'fun', 'bed'],
#  ['oh', 'son', 'old', 'know', 'well'],
#  ['hmmm', 'oh', 'baby', 'mmmm', 'yeah'],
#  ['gag', 'ice', 'cub'],
#  ['homer', 'homer', 'record'],
#  ['hey',
#   'anybody',
#   'mind',
#   'serve',
#   'bartender',
#   'know',
#   'ph',
#   'd',
#   'mixology'],
#  ['hey', 'homer', 'care', 'try', 'flander', 'planter', 'punch'],
#  ['hey', 'flander', 'time', 'little', 'alcohol'],
#  ['au',
#   'contraire',
#   'simpson',
#   'shot',
#   'rum',
#   'jigger',
#   'bourbon',
#   'little',
#   'dab',
#   'roo',
#   'creme',
#   'de',
#   'cassis',
#   'flavor'],
#  ['warm', 'sense', 'ssslurre', 'shpeech', 'right'],
#  ['homer',
#   'easy',
#   'al',
#   'ky',
#   'hol',
#   'remember',
#   'year',
#   'winfield',
#   'party',
#   'throw',
#   'laundry',
#   'hamper'],
#  ['hi',
#   'homer',
#   'sister',
#   'law',
#   'right',
#   'remember',
#   'remember',
#   'beau',
#   'tiful'],
#  ['ow', 'hey', 'jeez'],
#  ['new', 'kind', 'mace', 'painful'],
#  ['oh', 'dr', 'hibbert', 'enjoy', 'party'],
#  ['uh', 'slip', 'novelty', 'ice', 'cube', 'fake', 'fly', 'drink'],
#  ['homer',
#   'novelty',
#   'ice',
#   'cube',
#   'highly',
#   'toxic',
#   'chemical',
#   'ironically',
#   'real',
#   'fly',
#   'sanitary'],
#  ['look', 'face', 'priceless'],
#  ['little', 'monkey', 'little', 'monkey'],
#  ['bart', 'thing', 'cute'],
#  ['hey', 'everybody', 'look', 'funniest', 'guy', 'world'],
#  ['oh', 'homer', 'king'],
#  ['wantin', "'", 'tell', 'year', 'nerve'],
#  ['homer', 'know', 'wife', 'wife', 'friend', 'meet', 'hour', 'ago'],
#  ['stink', 'lousy', 'operation', 'stink', 'quit'],
#  ['uh', 'gee', 'homer', 'quit'],
#  ['handful', 'peanut', 'maude'],
#  ['hey', 'thank', 'invitin', "'", 'wonderful', 'time'],
#  ['want', 'live', 'night', 'suggest', 'roll'],
#  ['hmmm', 'thank', 'dr', 'hibbert', 'thank', 'come'],
#  ['want', 'sure', 'kid', 'hear', 'young', 'hate', 'know', 'parent', 'fight'],
#  ['music', 'send', 'chill', 'spine'],
#  ['homer', 'remember', 'way', 'act', 'party', 'night'],
#  ['say', 'wet', 'clothe', 'dry', 'martini'],
#  ['good', 'lord', 'fly', 'drink'],
#  ['slip', 'glass', 'gag'],
#  ['pronounce', 'whimsical', 'jape', 'season'],
#  ['homer',
#   'like',
#   'think',
#   'patient',
#   'tolerant',
#   'woman',
#   'line',
#   'cross',
#   'stop',
#   'love',
#   'night',
#   'cross',
#   'line',
#   'throw'],
#  ['sorry', 'honey', 'forget', 'church'],
#  ['go', 'church', 'today', 'go', 'stay', 'explain', 'bart', 'scar', 'life'],
#  ['oh', 'mean', 'inside'],
#  ['night',
#   'notice',
#   'daddy',
#   'act',
#   'little',
#   'strange',
#   'probably',
#   'understand'],
#  ['admit', 'know', 'sorry', 'happen', 'hope', 'lose', 'lot', 'respect'],
#  ['sneak',
#   'preview',
#   'week',
#   'sermon',
#   'announcement',
#   'new',
#   'pamphlet',
#   'available',
#   'church',
#   'newsrack',
#   'include',
#   'bible',
#   'bafflers',
#   'satan',
#   'boners',
#   'good',
#   'grief',
#   'satan',
#   'boner',
#   'teen',
#   'cool',
#   'fry',
#   'hell'],
#  ['sorry',
#   'lord',
#   'compete',
#   'squeaking',
#   'homer',
#   'simpson',
#   'shoe',
#   'hold',
#   'take',
#   'seat'],
#  ['mrs',
#   'lovejoy',
#   'hold',
#   'annual',
#   'marriage',
#   'retreat',
#   'weekend',
#   'catfish',
#   'lake',
#   'psychological',
#   'counseling',
#   'couple',
#   'marriage',
#   'hang',
#   'thread'],
#  ['need', 'tune'],
#  ['wish', 'participate', 'sign', 'way', 'service'],
#  ['simpson', 'attend', 'little', 'retreat'],
#  ['oh', 'tempting', 'wonderful', 'idea'],
#  ['marriage', 'encounter', 'weekend', 'come'],
#  ['hold', 'catfish', 'lake', 'catfish', 'lake', 'catfish'],
#  ['go', 'retreat', 'marriage', 'tune', 'fishing'],
#  ['hello', 'mrs', 'simpson'],
#  ['oh', 'suppose', 'sitter', 'short', 'notice'],
#  ['oh', 'dear', 'find', 'babysitter', 'kick', 'tooth'],
#  ['need', 'babysitter', 'half'],
#  ['tone', 'young', 'lady', 'taste', 'hand'],
#  ['wonder', 'think', 'babysit', 'kid', 'weekend', 'ask', 'desperate'],
#  ['oh',
#   'sure',
#   'resort',
#   'old',
#   'grampa',
#   'feeb',
#   'guy',
#   'count',
#   'dagnabit',
#   'agin'],
#  ['marge', 'puttin', "'", 'thing', 'trunk'],
#  ['maggie',
#   'run',
#   'fever',
#   'number',
#   'stick',
#   'finger',
#   'electrical',
#   'socket',
#   'number',
#   'drink',
#   'pine',
#   'cleanser'],
#  ['right', 'right', 'goodbye', 'child', 'behave'],
#  ['number', 'grampa', 'fall', 'bathtub'],
#  ['grampa', 'mom', 'hurry', 'forget', 'list', 'thing', 'lisa'],
#  ['uh', 'huh', 'uh', 'huh', 'allow', 'smoke', 'cigar'],
#  ['whoa', 'better', 'gas'],
#  ['fill', "'", 'er', 'guess', 'stretch', 'leg'],
#  ['oh', 'general', 'sherman', 'ya'],
#  ['wait', 'wait', 'minute', 'wait', 'minute', 'general', 'sherman'],
#  ['big', 'catfish', 'part'],
#  ['weigh', 'upwards', 'pound'],
#  ['know', 'picture', 'general', 'exactly', 'freakishly', 'big'],
#  ['hmmmm', 'gentleman', 'go', 'catch', 'general', 'sherman'],
#  ['supermarket',
#   'video',
#   'store',
#   'grab',
#   'krusty',
#   'burger',
#   'head',
#   'arcade'],
#  ['bart',
#   'grampa',
#   'kindly',
#   'old',
#   'man',
#   'trust',
#   'sure',
#   'right',
#   'advantage'],
#  ['lis',
#   'crazy',
#   'topsy',
#   'turvy',
#   'time',
#   'right',
#   'wrong',
#   'right',
#   'gut',
#   'tell',
#   'bleed',
#   'gramp',
#   'dry'],
#  ['ah', 'mr', 'mrs', 'simpson', 'welcome'],
#  ['hello', 'reverend', 'glad', 'come', 'oh', 'hello', 'helen'],
#  ['hel', 'lo', 'marge'],
#  ['homer', 'simpson', 'marriage', 'little', 'spit', 'shine'],
#  ['uh', 'uh', 'reverend', 'go', 'to', 'chance', 'fishing'],
#  ['oh', 'afraid', 'marriage', 'reconcile', 'hour', 'homer', 'take', 'weekend'],
#  ['bait',
#   'hook',
#   'honesty',
#   'way',
#   'happy',
#   'marriage',
#   'will',
#   'get',
#   'away'],
#  ['understand', 'bowling', 'expression'],
#  ['ah',
#   'couple',
#   'good',
#   'turnout',
#   'room',
#   'introduce',
#   'tell',
#   'little',
#   'bit',
#   'john',
#   'gloria'],
#  ['gloria',
#   'johnny',
#   'boy',
#   'able',
#   'cut',
#   'manwise',
#   'time',
#   'want',
#   'odor',
#   'gin',
#   'sour',
#   'defeat',
#   'press'],
#  ['thank', 'gloria', 'john', 'tell', 'little'],
#  ['cook', 'keep', 'filthy', 'house', 'talk', 'profanely', 'queen', 'harpy'],
#  ['come', 'right', 'place', 'want', 'look', 'eye'],
#  ['eye', 'forget', 'beautiful'],
#  ['remember',
#   'save',
#   'life',
#   'bring',
#   'happiness',
#   'pass',
#   'collection',
#   'plate',
#   'week',
#   'right',
#   'ned',
#   'maude',
#   'bring'],
#  ['maude', 'god', 'bless', 'underline', 'passage', 'bible', 'find'],
#  ['lucky', 'gun', 'house'],
#  ['ohhh', 'get', 'drunk', 'look', 'dress'],
#  ['homer', 'marge', 'go', 'tell', 'fault', 'tell'],
#  ['come', 'homer', 'fault'],
#  ['marge', 'interrupt', 'turn'],
#  ['love', 'guy', 'stick', 'self', 'center'],
#  ['forget',
#   'birthdays',
#   'anniversarie',
#   'holiday',
#   'religious',
#   'secular',
#   'chew',
#   'mouth',
#   'open',
#   'gamble',
#   'hang',
#   'seedy',
#   'bar',
#   'bum',
#   'lowlife'],
#  ['blow', 'nose', 'towel', 'put', 'middle'],
#  ['half', 'gallon', 'chocolate'],
#  ['half', 'gallon', 'chocolate', 'brownie', 'fudge'],
#  ['half',
#   'gallon',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chip'],
#  ['mom', 'write', 'shopping', 'list'],
#  ['hey', 'grampa', 'aisle', 'step'],
#  ['drink',
#   'carton',
#   'change',
#   'baby',
#   'go',
#   'sleep',
#   'make',
#   'chew',
#   'noise',
#   'wake',
#   'make',
#   'honk',
#   'noise',
#   'oh',
#   'oh',
#   'scratch',
#   'key',
#   'guess',
#   'oh',
#   'wait',
#   'kick',
#   'sleep',
#   'toenail',
#   'long',
#   'yellow',
#   'think',
#   'right',
#   'guess',
#   'tired',
#   'want',
#   'thank',
#   'let',
#   'thing',
#   'chest'],
#  ['miss', 'luau', 'night'],
#  ['want', 'hear', 'mcbain', 'cannon', 'regulation', 'department', 'book'],
#  ['know', 'kid', 'gettin', "'", 'pretty', 'late'],
#  ['yeah', 'bed', 'grampa', 'big', 'day'],
#  ['use', 'kid', 'have', 'ethical', 'crisis'],
#  ['catch',
#   'general',
#   'sherman',
#   'thirty',
#   'clean',
#   'eat',
#   'thirty',
#   'bed',
#   'seven',
#   'incriminate',
#   'evidence',
#   'perfect',
#   'crime'],
#  ['homer',
#   'sneak',
#   'fishing',
#   'believe',
#   'selfishness',
#   'fishing',
#   'anytime',
#   'try',
#   'save',
#   'marriage',
#   'think',
#   'fish',
#   'talk',
#   'right',
#   'right'],
#  ['good', 'time', 'honest'],
#  ['right', 'help', 'marge', 'good', 'guy'],
#  ['right', 'sleep', 'walk'],
#  ['get',
#   'to',
#   'good',
#   'husband',
#   'get',
#   'to',
#   'good',
#   'husband',
#   'get',
#   'to',
#   'good',
#   'husband'],
#  ['hey', 'kid', 'forgot', 'whoa'],
#  ['ahead',
#   'general',
#   'sherman',
#   'waste',
#   'strength',
#   'big',
#   'ugly',
#   'catfish',
#   'get',
#   'to',
#   'skillet',
#   'stick',
#   'butter'],
#  ['sure', 'ma', 'let', 'kid', 'drink', 'coffee'],
#  ['hey',
#   'milhouse',
#   'big',
#   'blowout',
#   'casa',
#   'de',
#   'simpson',
#   'adult',
#   'frail',
#   'old'],
#  ['bart', 'joint', 'uh', 'twoish', 'square'],
#  ['tell', 'friend', 'right', 'get', 'pretty', 'funky', 'friend'],
#  ['right', 'noon', 'invite', 'party'],
#  ['trust', 'exercise', 'fall', 'backwards', 'rely', 'spouse', 'catch'],
#  ['husband',
#   'recommend',
#   'marge',
#   'train',
#   'marriage',
#   'counselor',
#   'instance',
#   'tell',
#   'partner',
#   'percent',
#   'right',
#   'fault',
#   'willing',
#   'certificate',
#   'frame'],
#  ['send', 'word', 'send', 'word'],
#  ['yanks', 'comin', "'"],
#  ['okay',
#   'fish',
#   'probably',
#   'wonder',
#   'catch',
#   'famous',
#   'fisherman',
#   'right',
#   'bald',
#   'guy',
#   'cable',
#   'fishing'],
#  ['whoa', 'holy', 'mackerel'],
#  ['milhouse', 'good', 'pal', 'happen', 'man'],
#  ['cherry', 'party', 'bart', 'chick'],
#  ['obvious', 'degrade', 'set', 'child', 'right', 'movement', 'decade', 'come'],
#  ['great', 'party', 'lisa', 'great'],
#  ['hey', 'shut', 'door', 'stop', 'away', 'stop', 'oh'],
#  ['haw', 'haw', 'haw'],
#  ['young', 'hellion', 'want', 'belt'],
#  ['yeah',
#   'care',
#   'man',
#   'hey',
#   'thank',
#   'come',
#   'hey',
#   'nice',
#   'tie',
#   'nelson'],
#  ['ah', 'thanks', 'dad'],
#  ['try', 'good', 'baby', 'sitter', 'fail', 'feeb', 'useless', 'old', 'wear'],
#  ['lisa', 'strong', 'unpleasant', 'feeling'],
#  ['call', 'remorse', 'vile', 'burlesque', 'irrepressible', 'youth'],
#  ['grab', 'bucket', 'brush', 'clean', 'harder', 'faster'],
#  ['champion', 'champion', 'time', 'loser', 'cause', 'champion', 'worlllld'],
#  ['hi', 'honey', 'uh', 'oh', 'marriage', 'retreat', 'go'],
#  ['come',
#   'retreat',
#   'think',
#   'marriage',
#   'trouble',
#   'minute',
#   'think',
#   'trouble',
#   'homer',
#   'expect',
#   'believe'],
#  ['marge',
#   'know',
#   'fish',
#   'mean',
#   'fish',
#   'represent',
#   'well',
#   'life',
#   'fish',
#   'make',
#   'champion',
#   'hero'],
#  ['weirdo', 'worm', 'store'],
#  ['fish', 'represent', 'selfish'],
#  ['way', 'feel', 'throw'],
#  ['oh', 'yeah', 'sure'],
#  ['wow',
#   'give',
#   'fame',
#   'breakfast',
#   'marriage',
#   'fight',
#   'hour',
#   'say',
#   'word',
#   'toss',
#   'tell',
#   'marriage',
#   'trouble',
#   'come',
#   'baby'],
#  ['oh', 'house', 'look', 'wonderful', 'grampa', 'secret'],
#  ['pretend',
#   'cry',
#   'right',
#   'hear',
#   'pretend',
#   'cry',
#   'turn',
#   'like',
#   'fawcet',
#   'boo',
#   'hoo',
#   'oh',
#   'cry',
#   'sad'],
#  ['trust', 'old', 'person'],
#  ['fool', 'long', 'sucker', 'hee', 'hee', 'hee'],
#  ['yup',
#   'general',
#   'sherman',
#   'pound',
#   'dwelling',
#   'fury',
#   'know',
#   'know',
#   'old',
#   'ask',
#   'people',
#   'year',
#   'day'],
#  ['fella',
#   'come',
#   'close',
#   'go',
#   'homer',
#   'seven',
#   'foot',
#   'tall',
#   'arm',
#   'like',
#   'tree',
#   'trunk',
#   'eye',
#   'like',
#   'steel',
#   'cold',
#   'hard',
#   'shock',
#   'hair',
#   'red',
#   'like',
#   'fire',
#   'hell'],
#  ['hurry', 'mom', 'convention', 'soon', 'good', 'comic_strip', 'go'],
#  ['wow', 'number', 'fallout', 'boy', 'ward'],
#  ['care', 'good', 'comic_strip', 'buy', 'casper', 'wimpy', 'ghost'],
#  ['think',
#   'sad',
#   'equate',
#   'friendliness',
#   'wimpiness',
#   'hope',
#   'achieve',
#   'true',
#   'popularity'],
#  ['know', 'think', 'think', 'casper', 'ghost', 'richie', 'rich'],
#  ['hey', 'look', 'alike'],
#  ['wonder', 'richie', 'die'],
#  ['realize', 'hollow', 'pursuit', 'money', 'take', 'life'],
#  ['kid', 'lighten', 'little'],
#  ['radioactive', 'man', 'rule', 'punch', 'bad', 'guy', 'say', 'cool'],
#  ['oh', 'yeah', 'look', 'knock', 'guy', 'sun', 'say', 'hot', 'ya'],
#  ['bad', 'come', 'dress', 'popular', 'cartoon', 'character'],
#  ['look', 'like', 'discount'],
#  ['uh',
#   'ahem',
#   'young',
#   'people',
#   'springfield',
#   'mayor',
#   'like',
#   'welcome',
#   'annual',
#   'funny',
#   'book',
#   'convention',
#   'thank',
#   'pump',
#   'dollar',
#   'local',
#   'economy'],
#  ['youthful',
#   'high',
#   'spirit',
#   'impart',
#   'glow',
#   'old',
#   'war',
#   'horse',
#   'feel',
#   'like',
#   'radiation',
#   'man'],
#  ['radioactive', 'man', 'jerk'],
#  ['stand',
#   'correct',
#   'fun',
#   'sure',
#   'clear',
#   'shriner',
#   'punk',
#   'make',
#   'fool',
#   'diamond',
#   'joe',
#   'quimby'],
#  ['excuse', 'sir', 'turn', 'left', 'vulcan', 'ear'],
#  ['let',
#   'get',
#   'utility',
#   'belt',
#   'couple',
#   'tricorder',
#   'light',
#   'saber',
#   'sorry',
#   'kid'],
#  ['hey', 'bart', 'dude'],
#  ['hey', 'otto', 'man', 'oooh'],
#  ['idea',
#   'comic',
#   'book',
#   'little',
#   'man',
#   'dude',
#   'drive',
#   'school',
#   'bus',
#   'day',
#   'night',
#   'fight',
#   'vampire',
#   'post',
#   'apocalyptic',
#   'warzone'],
#  ["c'mon", 'bart', 'go', 'buddy', 'hodge'],
#  ['guy', 'play', 'fallout', 'boy', 'tv'],
#  ['wow', 'guess', 'kill', 'vietnam'],
#  ['aaahh',
#   'laramie',
#   'cigarette',
#   'steady',
#   'nerve',
#   'need',
#   'combat',
#   'evil'],
#  ['gee',
#   'whilliker',
#   'radioactive',
#   'man',
#   'wisht',
#   'old',
#   'smoke',
#   'laramie'],
#  ['sorry', 'fallout', 'boy', 'sixteen'],
#  ['radioactive', 'man', 'act', 'time', 'save', 'earth'],
#  ['great',
#   "y'know",
#   'kids',
#   'sure',
#   'like',
#   'remember',
#   'actor',
#   'dirk',
#   'richter',
#   'portrayal',
#   'radioactive',
#   'man',
#   'sordid',
#   'detail',
#   'final',
#   'year',
#   'let',
#   'question',
#   'tasteful',
#   'okay',
#   'big',
#   'welcome',
#   'buddy',
#   'fallout',
#   'boy',
#   'hodge'],
#  ['radioactive',
#   'man',
#   'get',
#   'inject',
#   'shrink',
#   'serum',
#   'issue',
#   'thirty',
#   'come',
#   'costume',
#   'shrink'],
#  ['sure',
#   'know',
#   'finish',
#   'play',
#   'rum',
#   'tum',
#   'tugger',
#   'second',
#   'national',
#   'tour',
#   'company',
#   'cat',
#   'anybody'],
#  ['ooh', 'ooh', 'ooh', 'ooh', 'fallout', 'boy', 'oh', 'oh'],
#  ['yes', 'mask', 'boy'],
#  ['think',
#   'ghost',
#   'dirk',
#   'richter',
#   'haunt',
#   'bordello',
#   'bullet',
#   'riddled',
#   'body',
#   'find'],
#  ['dirk', 'richter', 'beautiful', 'man', 'little', 'vulture', 'leave'],
#  ['hey',
#   'radioactive',
#   'man',
#   'number',
#   'seventy',
#   'imaginary',
#   'tale',
#   'radioactive',
#   'man',
#   'marry',
#   'larva',
#   'girl'],
#  ['tell', 'special', 'promise', 'grubby', 'little', 'hand', '-PRON-'],
#  ['wow', 'radioactive', 'man', 'number'],
#  ['bet', 'worth', 'million', 'buck'],
#  ['lad', 'let', 'remind'],
#  ['moment', 'know', 'god', 'earth', 'know', 'buy', 'comic', 'book'],
#  ['emotion', 'place', 'son'],
#  ['yeah',
#   'mom',
#   'guess',
#   'dollar',
#   'man',
#   'sell',
#   'thirty',
#   'casper',
#   'dozen',
#   'lois',
#   'lane'],
#  ['know',
#   'superman',
#   'see',
#   'wonder',
#   'woman',
#   'golden',
#   'lariat',
#   'tie',
#   'time'],
#  ['kid', 'marge', 'hey', 'dinner', 'krusty', 'burger', 'treat'],
#  ['right',
#   'homer',
#   'whoa',
#   'sport',
#   'dad',
#   'take',
#   'fine',
#   'restaurant',
#   'like',
#   'krusty',
#   'burger'],
#  ['need', 'dollar', 'comic', 'book'],
#  ['buck', 'comic', 'book', 'draw', 'micha', 'ma', 'langelo'],
#  ['oh', 'dad', 'want', 'world'],
#  ['look',
#   'son',
#   'know',
#   'usually',
#   'bug',
#   'like',
#   'mad',
#   'try',
#   'show',
#   'pay',
#   'attention',
#   'know',
#   'go',
#   'to',
#   'dollar',
#   'go',
#   'to',
#   'stop',
#   'bug'],
#  ['hee', 'hee', 'win', 'face', 'yeah', 'like', 'apple', 'woo', 'hoo', 'hoo'],
#  ['gloat',
#   'homer',
#   'know',
#   'bart',
#   'age',
#   'thing',
#   'want',
#   'world',
#   'child',
#   'sized',
#   'electric',
#   'lightbulb',
#   'oven',
#   'parent',
#   'money',
#   'go',
#   'sister',
#   'patty',
#   'selma'],
#  ['uh', 'huh', 'slave'],
#  ['give', 'lot', 'free', 'time'],
#  ['uh', 'huh', 'let', 'smoking'],
#  ['month', 'work', 'work', 'sister', 'smoke', 'smoke'],
#  ['venus', 'oh', 'venus'],
#  ['want', 'dress', 'shield', 'hand', 'wash', 'drip', 'dry'],
#  ['big',
#   'day',
#   'finally',
#   'come',
#   'work',
#   'lightbulb',
#   'warm',
#   'treat',
#   'taste',
#   'extra',
#   'good'],
#  ['maybe', 'time', 'job', 'answer'],
#  ['aw', 'mom', 'ask', 'take', 'care', 'maggie', 'lisa', 'handful'],
#  ['mean', 'job', 'stupid'],
#  ['job',
#   'realize',
#   'time',
#   'little',
#   'piece',
#   'childhood',
#   'slip',
#   'away',
#   'forever'],
#  ['moment', 'dad', 'close'],
#  ['need', 'money', 'lot', 'money', 'ahh'],
#  ['ooh',
#   'good',
#   'like',
#   'deposit',
#   'defray',
#   'cost',
#   'jumbo',
#   'cherry',
#   'squishie'],
#  ['today', 'need', 'dime'],
#  ['oh', 'good', 'learn', 'trade'],
#  ['americanize', 'good', 'man'],
#  ['coin', 'worth', 'lousy', 'cent'],
#  ['let', 'good', 'time', 'roll'],
#  ['oh', 'humiliating', 'feel', 'like', 'geek'],
#  ['terrible', 'car', 'slow', 'laugh', 'buying'],
#  ['maybe', 'need', 'play', 'sympathy', 'let'],
#  ['ah', 'ha', 'look', 'pathetic'],
#  ['lemonade', 'suck', 'need', 'new', 'product', 'let', 'ah'],
#  ['form',
#   'line',
#   'crowd',
#   'cheap',
#   'beer',
#   'sympathetic',
#   'ear',
#   'step',
#   'right'],
#  ['ah', 'bart', 'credit', 'little', 'short', 'week'],
#  ['uh', 'get', 'liquor', 'license', 'young', 'fella'],
#  ['ugh', 'dog', 'eat'],
#  ['get', 'to', 'license', 'sell', 'beer'],
#  ['write', 'ticket', 'guy', 'thirsty', 'couple', 'house'],
#  ['ell', 'see', 'offense'],
#  ['long', 'officer', 'uh', 'oh'],
#  ['beer', 'beer', 'beautiful', 'beer'],
#  ['poor', 'boy', 'desperate', 'want', 'earn', 'money', 'buy', 'comic', 'book'],
#  ['comic', 'book', 'oh', 'boy', 'change', 'nazi', 'smasher'],
#  ['send', 'house', 'get', 'chore', 'know', 'mix', 'whitewash'],
#  ['eh', 'burt', 'simpson', 'look', 'like', 'get', 'strong', 'young'],
#  ['like',
#   'eat',
#   'get',
#   'dry',
#   'apricots',
#   'almond',
#   'paste',
#   'sauerkraut',
#   'candy'],
#  ['oh', 'brother', 'asa', 'kill', 'great', 'war', 'hold', 'grenade', 'long'],
#  ['kaiser',
#   'bill',
#   'special',
#   'delivery',
#   'uncle',
#   'sam',
#   'boy',
#   'd',
#   'company',
#   'yeah',
#   'johnny',
#   'harrison',
#   'brooklyn',
#   'bob',
#   'reggie',
#   'yeah',
#   'reggie',
#   'be',
#   'stuck',
#   'know'],
#  ['ribbon', 'candy', 'boy', 'love', 'candy'],
#  ['boy', 'love', 'candy'],
#  ['oh', 'yes', 'madam'],
#  ['ugh', 'think', 'work', 'madam'],
#  ['start', 'little', 'light', 'yard', 'work', 'nice', 'barley', 'pop'],
#  ['want', 'clear', 'weed', 'know', 'one', 'weed'],
#  ['careful', 'inside', 'watch', 'story'],
#  ['filthy', 'genuinely', 'arouse'],
#  ['merciful', 'heaven', 'bleed', 'iodine'],
#  ['listen', 'lady', 'yaaauuuuggghhh'],
#  ['think', 'mrs', 'glick', 'nice', 'poor', 'old', 'thing', 'anybody'],
#  ['sludge', 'certainly', 'collect', 'downspout'],
#  ['sludge', 'old', 'bat'],
#  ['today', 'wash', 'beulah', 'know'],
#  ['old', 'lady', 'thing', 'hear', 'year'],
#  ['wedding', 'dress', 'dye', 'black', 'mourning', 'dress'],
#  ['great', 'story', 'lady'],
#  ['night', 'dream', 'hold', 'arm'],
#  ['iodine', 'burn', 'germ', 'torch', 'amputate', 'arm', 'yaaauuuggghhh'],
#  ['payday', 'wager', 'look', 'forward'],
#  ['deserve', 'penny', 'know', 'tell', 'lot', 'girlfriend', 'chore'],
#  ['listen',
#   'lady',
#   'leave',
#   'scream',
#   'leave',
#   'say',
#   'bad',
#   'word',
#   'way',
#   'say',
#   'thank'],
#  ['welcome', 'right', 'spend', 'penny', 'whistle', 'moon', 'pie'],
#  ['moon', 'pie', 'butt', 'somebody', 'oughta', 'moon', 'pie'],
#  ['bustin', "'", 'hump', 'week', 'withered', 'old', 'clam', 'get', 'cent'],
#  ['hey', 'age', 'cent', 'lot', 'money'],
#  ['dad', 'get', 'thirty', 'buck', 'ugh', 'work', 'work', 'chump'],
#  ['son', 'proud', 'twice', 'age', 'figure'],
#  ['buck', 'forget', 'stool'],
#  ['get',
#   'sell',
#   'seed',
#   'visit',
#   'aunt',
#   'nursing',
#   'home',
#   'fish',
#   'dime',
#   'sewer',
#   'god',
#   'sake'],
#  ['freakin',
#   "'",
#   'kid',
#   'need',
#   'get',
#   'master',
#   'degree',
#   'folklore',
#   'mythology'],
#  ['excuse', 'carl', 'yastrzemski', 'baseball', 'card', 'big', 'sideburn'],
#  ['thirty', 'buck', 'be', 'get', 'be', 'gettin', "'", 'stool'],
#  ['wait',
#   'minute',
#   'martin',
#   'milhouse',
#   'go',
#   'buy',
#   'copy',
#   'radioactive',
#   'man',
#   'right'],
#  ['freakin', "'", 'kid'],
#  ['look', 'pal', 'get', 'buck', 'like', 'buy', 'radioactive', 'man', 'waddle'],
#  ['wow', 'breathe', 'boy'],
#  ['smell', 'like', 'grandpa'],
#  ['uh', 'oh', 'look', 'like', 'rain', 'better', 'baby', 'home'],
#  ['look', 'like', 'buy', 'bargain'],
#  ['pant', 'catch', 'barbed', 'wire', 'good', 'lord', 'choke', 'bomb'],
#  ['radioactive', 'day', 'forward', 'shall', 'radioactive', 'man'],
#  ['think', 'hit', 'atomic', 'bomb', 'kill'],
#  ['turn', 'page', 'bart'],
#  ['listen', 'guy', 'welcome', 'come', 'read', 'time', 'like'],
#  ['house', 'crazy', 'talk'],
#  ['guy',
#   'bart',
#   'monday',
#   'thursdays',
#   'milhouse',
#   'tuesday',
#   'friday',
#   'truly',
#   'wednesday',
#   'saturday'],
#  ['wait', 'minute', 'sunday'],
#  ['sunday',
#   'possession',
#   'determine',
#   'random',
#   'number',
#   'generator',
#   'digits',
#   'milhouse',
#   'bart',
#   'seven'],
#  ['wait', 'minute', 'zero'],
#  ['unlikely',
#   'event',
#   'zero',
#   'possession',
#   'determine',
#   'rock',
#   'scissor',
#   'paper',
#   'competition',
#   'best'],
#  ['excellent', 'today', 'saturday', 'gentleman', 'guess', 'take', 'comic'],
#  ['uh',
#   'uh',
#   'uh',
#   'ah',
#   'nice',
#   'try',
#   'martin',
#   'work',
#   'tonight',
#   'comic',
#   'book',
#   'stay',
#   'right'],
#  ['comic', 'book', 'stay', 'right'],
#  ['fine',
#   'go',
#   'stay',
#   'comic',
#   'book',
#   'like',
#   'sleep',
#   'yeah',
#   'sleep',
#   'pal',
#   'right',
#   'real',
#   'friendly',
#   'like'],
#  ['nice', 'try', 'mister'],
#  ['milhouse',
#   'acid',
#   'hand',
#   'damage',
#   'newsprint',
#   'want',
#   'comic',
#   'forever',
#   'alive',
#   'honor',
#   'bury'],
#  ['know', 'make', 'sap', 'bartholemew', 'j', 'simpson'],
#  ['think', 'boy', 'like', 'milk', 'microwave', "s'mores"],
#  ['thank', 'mrs', 'simpson'],
#  ['sweet', 'dreams', 'boy'],
#  ['step', 'dead', 'man'],
#  ['yeah', 'right', 'gettin', "'"],
#  ['dear', 'friend', 'martin', 'try', 'steal', 'comic', 'book'],
#  ['bart', 'treat', 'guest'],
#  ['quiet', 'piggy', 'stick', 'apple', 'mouth', 'chance', 'turn', 'watch'],
#  ['oh',
#   'little',
#   'game',
#   'let',
#   'old',
#   'bart',
#   'nice',
#   'drowsy',
#   'turn',
#   'wham'],
#  ['go', 'crazy', 'bart', 'tell', 'mom'],
#  ['hey', 'martin', 'tell', 'squealer'],
#  ['know', 'bad', 'people', 'bathroom'],
#  ['homer', 'come', 'check', 'boy'],
#  ['milhouse', 'far', 'ground', 'rain', 'probably', 'soften', 'bit'],
#  ['know', 'guy', 'tie', 'save', 'comic', 'speak'],
#  ['help',
#   'bart',
#   'want',
#   'comic',
#   'want',
#   'carl',
#   'yastrzemski',
#   'big',
#   'burn'],
#  ['boy', 'better', 'come', 'house', 'want', 'sniffle'],
#  ['come',
#   'play',
#   'little',
#   'tie',
#   'game',
#   'inside',
#   'get',
#   'cocoa',
#   'stove',
#   'want',
#   'imitation',
#   'marshmallow'],
#  ['raise', 'hand', 'mrs', 'simpson'],
#  ['use', 'fellow', 'comic', 'book', 'return', 'earth', 'come'],
#  ['work', 'hard', 'go', 'end', 'share'],
#  ['world', 'safe', 'long'],
#  ['ah',
#   'chief',
#   'wiggum',
#   'archbishop',
#   'mcgee',
#   'distinguish',
#   'guest',
#   'pleased',
#   'dedicate',
#   'emergency',
#   'warning',
#   'system',
#   'uh',
#   'chance',
#   'nuclear',
#   'disaster',
#   'sign',
#   'tell',
#   'good',
#   'citizen',
#   'springfield'],
#  ['joke', 'core', 'explode', 'will', 'power', 'light', 'sign'],
#  ['like',
#   'present',
#   'man',
#   'sign',
#   'possible',
#   'drop',
#   'obstructionist',
#   'legal',
#   'challenge',
#   'montgomery',
#   'burn'],
#  ['mr', 'burns', 'late', 'terribly', 'wrong'],
#  ['better', 'leave', 'diamond', 'joe', 'quimby', 'hold', 'bag'],
#  ['turn', 'get', 'greet', 'dignitary'],
#  ['oh', 'mr', 'burns', 'get', 'doctor'],
#  ['absolutely',
#   'quack',
#   'sawbone',
#   'go',
#   'apply',
#   'leech',
#   'long',
#   'ounce',
#   'strength',
#   'leave'],
#  ['mmmm',
#   'mr',
#   'burns',
#   'suffer',
#   'medical',
#   'man',
#   'hypohemia',
#   'layman',
#   'term',
#   'simply',
#   'lack',
#   'blood'],
#  ['damn', 'doctor', 'idiot', 'know', 'hypohemia', 'want', 'know'],
#  ['point', 'hope', 'transfusion'],
#  ['long', 'sterilize', 'needle'],
#  ['afraid', 'simple', 'blood', 'type', 'double', 'o', 'negative', 'rare'],
#  ['b', 'positive', 'damn', 'common', 'gutter', 'blood', 'vein'],
#  ['smither', 'feel', 'bad', 'kidney', 'donate', 'hit', 'spot'],
#  ['hair', 'head', 'look'],
#  ['attention',
#   'employee',
#   'boss',
#   'inspiration',
#   'mr',
#   'burns',
#   'death',
#   'death',
#   'door',
#   'type',
#   'double',
#   'o',
#   'negative',
#   'blood',
#   'implore',
#   'report',
#   'bloodmobile',
#   'outside'],
#  ['believe',
#   'guy',
#   'human',
#   'million',
#   'dollar',
#   'need',
#   'help',
#   'wanna',
#   'cash',
#   'loser',
#   'stick',
#   'crummy',
#   'dead',
#   'end',
#   'job'],
#  ['know', 'homer', 'supervisor'],
#  ['lee', 'mur', 'lee', 'mur'],
#  ['zee', 'boo', 'zee', 'boo'],
#  ['try', 'teach', 'maggie', 'nature', 'end', 'barnyard', 'want', 'advantage'],
#  ['lisa', 'good', 'zebu'],
#  ['like', 'ox', 'hump', 'dewlap', 'hump', 'dew', 'lap', 'hump', 'dew', 'lap'],
#  ['marge', 'marge', 'blood', 'type'],
#  ['aw', 'nut', 'extremely', 'rare', 'blood'],
#  ['know', 'blood', 'type', 'romantic'],
#  ['mother', 'know', 'family'],
#  ['oh', 'yeah', 'shoe', 'size'],
#  ['sixteen', 'permanent', 'baby'],
#  ['want', 'wear', 'ring', 'look', 'cheap'],
#  ['butterscotch', 'imitation', 'butterscotch'],
#  ['glow', 'dark', 'monster'],
#  ['oh', 'homie', 'lot', 'hair', 'want', 'know', 'blood', 'type'],
#  ['aw',
#   'old',
#   'man',
#   'burns',
#   'go',
#   'to',
#   'kick',
#   'double',
#   'o',
#   'negative',
#   'blood',
#   'plant'],
#  ['woo',
#   'yes',
#   'right',
#   'woo',
#   'congratulation',
#   'boy',
#   'get',
#   'date',
#   'needle'],
#  ['hey', 'wait', 'minute', 'blood', 'right', 'know'],
#  ['yeah', 'right', 'remain', 'silent'],
#  ['bart', 'help', 'need', 'decent', 'thing'],
#  ['bart',
#   'like',
#   'ask',
#   'blood',
#   'free',
#   'crazy',
#   'little',
#   'young',
#   'understand',
#   'save',
#   'rich',
#   'man',
#   'life',
#   'shower',
#   'rich',
#   'know',
#   'story',
#   'hercule',
#   'lion'],
#  ['yeah',
#   'probably',
#   'time',
#   'big',
#   'mean',
#   'lion',
#   'get',
#   'thorn',
#   'paw',
#   'village',
#   'people',
#   'try',
#   'pull',
#   'strong',
#   'get',
#   'hercule',
#   'hercule',
#   'mighty',
#   'strength',
#   'bingo',
#   'moral',
#   'lion',
#   'happy',
#   'give',
#   'hercule',
#   'big',
#   'thing',
#   'rich'],
#  ['hey', 'let', 'emergency', 'life', 'death'],
#  ['whoa', 'otto', 'man', 'work'],
#  ['oh',
#   'yeah',
#   'day',
#   'friend',
#   'school',
#   'get',
#   'job',
#   'certify',
#   'bloodlette',
#   'tech',
#   'dude'],
#  ['okay', 'let', 'wash'],
#  ['homer', 'brave', 'young', 'bart', 'know', 'hug'],
#  ['smither', 'go', 'want', 'dictate', 'epitaph'],
#  ['charles', 'montgomery', 'burns'],
#  ['american', 'patriot'],
#  ['o', 'tyrant', 'hear', 'mighty', 'quake', 'smither'],
#  ['oh', 'o', "'", 'mornin', "'", 'ye', 'look', 'good', 'old'],
#  ['hi', 'mr', 'burns'],
#  ['oh', 'hey', 'mr', 'brown', 'shoe', 'local', 'sport', 'team', 'hm'],
#  ['mr', 'burns', 'okay', 'jackpot'],
#  ['heh', 'heh', 'heh', 'game', 'hasta', 'manana', 'osvaldo'],
#  ['smither', 'pink', 'pith', 'vinegar'],
#  ['know',
#   'funny',
#   'smither',
#   'try',
#   'tincture',
#   'poultice',
#   'tonic',
#   'patent',
#   'medicine',
#   'need',
#   'blood',
#   'young',
#   'boy',
#   'way',
#   'lad'],
#  ['uh', 'bart', 'simpson', 'sir'],
#  ['son', 'homer', 'simpson', 'stiff', 'sector', 'g'],
#  ['simpson', 'get', 'nice', 'surprise', 'mail', 'nice'],
#  ['bill',
#   'bill',
#   'summons',
#   'bill',
#   'wait',
#   'minute',
#   'c',
#   'm',
#   'burn',
#   'yes',
#   'woo',
#   'hoo',
#   'woo'],
#  ['marge', 'lisa', 'maggie', 'let', 'yard', 'neighbor'],
#  ['lisa', 'dim', 'light', 'turn', 'light'],
#  ['little', 'thin', 'okay', 'check'],
#  ['well', 'half', 'marge', 'well', 'half'],
#  ['right',
#   'check',
#   'card',
#   'panic',
#   'sure',
#   'tell',
#   'get',
#   'pick',
#   'dear',
#   'bart',
#   'thank',
#   'kindly',
#   'blood',
#   'truly',
#   'montgomery',
#   'burn',
#   'card'],
#  ['way',
#   'gratitude',
#   'gold',
#   'diamond',
#   'ruby',
#   'lousy',
#   'card',
#   'wait',
#   'minute',
#   'card',
#   'get',
#   'mad',
#   'place'],
#  ['homer',
#   'thing',
#   'like',
#   'reward',
#   'fellow',
#   'human',
#   'need',
#   'help',
#   'hand'],
#  ['marge',
#   'wife',
#   'love',
#   'live',
#   'world',
#   'believe',
#   'flower',
#   'bell',
#   'leprechaun',
#   'magic',
#   'frog',
#   'funny',
#   'little',
#   'hat'],
#  ['yeah', 'mom', 'get', 'hose'],
#  ['get', 'exactly', 'want', 'give', 'old', 'man', 'second', 'chance'],
#  ['promise',
#   'boy',
#   'simple',
#   'thing',
#   'lot',
#   'rich',
#   'man',
#   'break',
#   'promise',
#   'bart',
#   'letter'],
#  ['dear',
#   'mr',
#   'burns',
#   'glaaad',
#   'enjoy',
#   'son',
#   'blood',
#   'caard',
#   'great',
#   'case',
#   'tell',
#   'sarcastic',
#   'stink',
#   'read'],
#  ['good',
#   'senile',
#   'buck',
#   'toothe',
#   'old',
#   'mummy',
#   'bony',
#   'girl',
#   'arm',
#   'smell',
#   'like'],
#  ['boss', 'mail', 'right', 'minute'],
#  ['angry', 'homer', 'sleep'],
#  ['oh', 'right', 'hand', 'thing', 'usually', 'work'],
#  ['homer', 'breakfast', 'ready'],
#  ['oh',
#   'marge',
#   'save',
#   'make',
#   'big',
#   'mistake',
#   "y'know",
#   'finally',
#   'understand',
#   'meaning',
#   'mmphm',
#   'hnmph'],
#  ['homer', 'think', 'cornstarch', 'canister'],
#  ['bart', 'see', 'letter'],
#  ['right', 'think', 'carefully'],
#  ['shove', 'mailbox'],
#  ['dad',
#   'thing',
#   'letter',
#   'say',
#   'know',
#   'emotional',
#   'guy',
#   'mad',
#   'night',
#   'guarantee',
#   'mad',
#   'morning'],
#  ['homer', 'encourage', 'strangle'],
#  ['right',
#   'okay',
#   'think',
#   'homer',
#   'panic',
#   'pick',
#   'mail',
#   'till',
#   'noon',
#   'time'],
#  ['ow', 'ow', 'ow', 'ow', 'ow', 'ow', 'ow'],
#  ['homer', 'lock', 'tight'],
#  ['lock',
#   'eh',
#   'little',
#   'surprise',
#   'sleeve',
#   'old',
#   'mr',
#   'lock',
#   'step',
#   'aside',
#   'boy'],
#  ['hey', 'homer', 'fight', 'power'],
#  ['look', 'like', 'letter', 'wet', 'ink', 'run', 'able', 'read'],
#  ['yeah', 'people', 'mail'],
#  ['people',
#   'will',
#   'letter',
#   'boo',
#   'hoo',
#   'know',
#   'kinda',
#   'letter',
#   'people',
#   'write',
#   'dear',
#   'somebody',
#   'hear',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'truly',
#   'bozo',
#   'big',
#   'loss'],
#  ['bart', 'eye', 'mailman', 'kind', 'signal'],
#  ['dear', 'god', 'plan', 'water', 'mail'],
#  ['uh',
#   'uh',
#   'guess',
#   'good',
#   'run',
#   'because',
#   'mail',
#   'lady',
#   'know',
#   'address',
#   'huh'],
#  ['go', 'to', 'run'],
#  ['want', 'world', 'hear', 'story', 'harrowing', 'struggle', 'hypohemia'],
#  ['sir', 'mr', 'roman', 'fine', 'ghostwriter', 'business'],
#  ['write', 'like', 'hell', 'muck', 'unsinkable', 'sadruddin', 'mahbaradad'],
#  ['right', 'right', 'question', 'sleep', 'famous'],
#  ['countess',
#   'van',
#   'zeplin',
#   'blaze',
#   'listen',
#   'bargain',
#   'basement',
#   'baudelaire',
#   'dizzy',
#   'starlet',
#   'stre',
#   'word',
#   'write',
#   'thing',
#   'fire'],
#  ['okay', 'mr', 'burns'],
#  ['great', 'plan', 'bart'],
#  ['ooh', 'look', 'maggie', 'dec', 'ah', 'edron', 'dodecahedron'],
#  ['lisa', 'know', 'strange', 'father', 'try', 'worry'],
#  ['chapter', 'fifth', 'trip', 'infirmary', 'unexpected', 'result'],
#  ['minute', 'till', 'burn', 'come', 'time', 'operation', 'mail'],
#  ['tell', 'go', 'to', 'destroy', 'family', 'believe'],
#  ['oh', 'frighten', 'letter', 'opener'],
#  ['hello', 'case', 'tell', 'sarcastic'],
#  ['stink',
#   'senile',
#   'buck',
#   'toothe',
#   'old',
#   'mummy',
#   'bony',
#   'girl',
#   'arm',
#   'smell',
#   'like',
#   'elephant',
#   'butt'],
#  ['hey', "c'mon", 'joey', 'twist', 'arm'],
#  ['homer', 'tell', 'job', 'okay'],
#  ['crush',
#   'like',
#   'ant',
#   'easy',
#   'revenge',
#   'dish',
#   'best',
#   'serve',
#   'cold',
#   'bide',
#   'time',
#   'oh',
#   'hell',
#   'crush',
#   'like',
#   'ant'],
#  ['senile',
#   'eh',
#   'buck',
#   'toothed',
#   'bony',
#   'arm',
#   'liver',
#   'spot',
#   'chinless'],
#  ['pink', 'slip', 'await', 'signature', 'sir'],
#  ['odd',
#   'rob',
#   'man',
#   'livelihood',
#   'feel',
#   'strangely',
#   'tell',
#   'smither',
#   'beat',
#   'pulp'],
#  ['oh', 'see', 'mr', 'burns', 'mad', 'kinda', 'mad'],
#  ['big', 'letter', 'writing', 'pen'],
#  ['honey', 'matter', 'happen', 'pull'],
#  ['okay',
#   'plan',
#   'sister',
#   'raise',
#   'kid',
#   'die',
#   'gutter',
#   'practical',
#   'mean'],
#  ['okay', 'bart', 'believe', 'try', 'scare'],
#  ['know', 'homer', 'simpson'],
#  ['yeah', 'nice', 'guy', 'play', 'poker'],
#  ['hmmm', 'huh', 'uh', 'need', 'beat'],
#  ['hold', 'kick', 'get'],
#  ['uh', 'um', 'umm'],
#  ['save', 'mr', 'burns', "'", 'life'],
#  ['close',
#   'gentle',
#   'reader',
#   'like',
#   'thank',
#   'thank',
#   'misprint',
#   'enjoy',
#   'write',
#   'book',
#   'enjoy',
#   'read',
#   'end'],
#  ['ah', 'smither', 'beating'],
#  ['sir', 'uh', 'beating'],
#  ['sorry', 'sir', 'hurt', 'homer', 'simpson', 'save', 'life'],
#  ['know',
#   'mad',
#   'think',
#   'fair',
#   'warn',
#   'go',
#   'stand',
#   'outside',
#   'gate',
#   'forgive'],
#  ['need',
#   'smither',
#   'usual',
#   'sober',
#   'ying',
#   'rage',
#   'yang',
#   "'",
#   'er',
#   'old',
#   'pal'],
#  ['sir', 'wish', 'handshake', 'end', 'afraid', 'simpson', 'matter', 'attend'],
#  ['moe', 'tavern', 'elite', 'meet', 'drink'],
#  ['eh', 'yeah', 'hello', 'mike', 'rotch'],
#  ['hold',
#   'check',
#   'mike',
#   'rotch',
#   'mike',
#   'rotch',
#   'hey',
#   'anybody',
#   'see',
#   'mike',
#   'rotch',
#   'lately'],
#  ['listen',
#   'little',
#   'puke',
#   'day',
#   'go',
#   'to',
#   'catch',
#   'go',
#   'to',
#   'carve',
#   'ice',
#   'pick'],
#  ['matter', 'homer', 'normal', 'effervescent', 'self'],
#  ['get', 'problem', 'moe'],
#  ['homer', 'hey', 'drink', 'forget', 'problem'],
#  ['yeah', 'drink', 'enhance', 'social', 'skill'],
#  ['simpson',
#   'present',
#   'extravagant',
#   'present',
#   'mad',
#   'unthinkable',
#   'utterly',
#   'impossible',
#   'present',
#   'frabulous',
#   'grabulous',
#   'zip',
#   'zoop',
#   'zabulous',
#   'present'],
#  ['pool', 'table', 'mad', 'go', 'to', 'turn', 'home', 'saloon'],
#  ['b', 'sir', 'thirty', 'thousand', 'dollar'],
#  ['dare', 'sully', 'moment', 'price', 'taggery', 'perfect'],
#  ['oh', 'mr', 'burns'],
#  ['heave', 'ho', 'heave', 'ho', 'heave', 'ho', 'heave', 'ho', 'heave', 'ho'],
#  ['wait', 'dad', 'smile'],
#  ['mr', 'burns', 'bring', 'present'],
#  ['think', 'go', 'beat', 'bloody', 'pulp'],
#  ['hard',
#   'feeling',
#   'advance',
#   'copy',
#   'book',
#   'rainbow',
#   'young',
#   'fellow',
#   'forget'],
#  ['open', 'crate', 'stupid'],
#  ['tell', 'bet', 'fill', 'diamond', 'ruby', 'sapphire', 'pearl'],
#  ['wow', 'big', 'ugly', 'head'],
#  ['actually',
#   'son',
#   'big',
#   'ugly',
#   'olmec',
#   'indian',
#   'head',
#   'carve',
#   'meso',
#   'american',
#   'indians',
#   'year',
#   'ago',
#   'gruesome',
#   'customer',
#   "xt'tapalatakettle",
#   'god',
#   'war'],
#  ['maggie', 'az', 'tec', 'old', 'mec', 'old', 'mec'],
#  ['let', 'acquaint', 'se', "xt'tapalatakettle", 'ta'],
#  ['sir', 'god', 'generosity'],
#  ['save',
#   'guy',
#   'life',
#   'whattaya',
#   'nothing',
#   'bad',
#   'nothing',
#   'big',
#   'scary',
#   'rock'],
#  ['hey', 'man', 'bad', 'mouth', 'head'],
#  ['homer', 'thought', 'count', 'moral', 'story', 'good', 'deed', 'reward'],
#  ['hey', 'get', 'reward', 'head', 'cool'],
#  ['guess', 'moral', 'good', 'deed', 'go', 'unrewarded'],
#  ['wait', 'minute', 'write', 'nasty', 'letter', 'get'],
#  ['guess', 'moral', 'squeaky', 'wheel', 'get', 'grease'],
#  ['exactly', 'bunch', 'stuff', 'happen'],
#  ['certainly', 'memorable', 'day'],
#  ['bart', 'bart', 'hey', 'bart'],
#  ['lisa', 'm', 'wrong', 'dad', 'die'],
#  ['bart',
#   'birthday',
#   'day',
#   'go',
#   'to',
#   'year',
#   'old',
#   'big',
#   'number',
#   'double',
#   'digit'],
#  ['enjoy',
#   'change',
#   'hit',
#   'big',
#   'oh',
#   'leg',
#   'start',
#   'candy',
#   'taste',
#   'good',
#   'anymore'],
#  ['bart', 'let', 'pour', 'little', 'heart'],
#  ['sorry', 'old', 'timer', 'ramble'],
#  ['bart',
#   'disappoint',
#   'birthday',
#   'thing',
#   'lose',
#   'break',
#   'hour',
#   'okay',
#   'forget'],
#  ['okay',
#   'uh',
#   'huh',
#   'okay',
#   'okay',
#   'okay',
#   'okay',
#   'okay',
#   'okay',
#   'birthday',
#   'gift',
#   'come',
#   'way'],
#  ['bart', 'watch', 'maggie', 'laundry'],
#  ['hm', 'krusty', 'hotline'],
#  ['hi',
#   'kid',
#   'reach',
#   'krusty',
#   'hotline',
#   'ask',
#   'parent',
#   "'",
#   'permission',
#   'naughty',
#   'naughty',
#   'krusty',
#   'forgive',
#   'dollar',
#   'minute',
#   'cent',
#   'additional',
#   'minute'],
#  ['thank', 'call', 'kid', 'new', 'message', 'day'],
#  ['bart', 'ask', 'watch', 'sister'],
#  ['try', 'stop', 'overpower'],
#  ['steal', 'shirt', 'steal', 'shirt'],
#  ['oh', 'thank', 'marge', 'pink'],
#  ['marge',
#   'wear',
#   'pink',
#   'shirt',
#   'work',
#   'everybody',
#   'wear',
#   'white',
#   'shirt',
#   'popular',
#   'different'],
#  ['homer', 'panic', 'plenty', 'white', 'shirt'],
#  ['oh', 'gimme', 'gimme', 'gimme', 'gimme', 'gimme'],
#  ['oh', 'pink', 'pink', 'pink', 'marge'],
#  ['ah', 'lucky', 'red', 'hat', 'clean', 'whistle'],
#  ['homer', 'go', 'notice', 'wear', 'pink', 'shirt', 'work'],
#  ['wait', 'minute', 'zoom', 'man', 'pink'],
#  ['oh', 'homer', 'simpson', 'sir', 'boob', 'sector', 'g'],
#  ['simpson',
#   'eh',
#   'judge',
#   'outlandish',
#   'attire',
#   'sort',
#   'free',
#   'thinking',
#   'anarchist'],
#  ['excellent', 'color', 'monitor', 'pay'],
#  ['hey', 'homer', 'save', 'doughnut'],
#  ['mmm',
#   'thank',
#   'look',
#   'hey',
#   'wait',
#   'minute',
#   'wear',
#   'pink',
#   'shirt',
#   'mean',
#   'kind',
#   'pink',
#   'doughnut',
#   'eater',
#   'tempt'],
#  ['understand', 'son', 'throw', 'red', 'hat', 'white', 'laundry'],
#  ['spare', 'tired', 'semantic', 'simpson', 'family', 'away'],
#  ['know',
#   'mr',
#   'burn',
#   'body',
#   'cavity',
#   'search',
#   'reveal',
#   'x',
#   'ray',
#   'time',
#   'maybe',
#   'tell',
#   'truth'],
#  ['cahoot', 'smither', 'recall', 'penchant', 'bell', 'trouser', "'"],
#  ['uh', 'sir', 'costume', 'plant', 'production', 'h', 'm', 's', 'pinafore'],
#  ['oh',
#   'yes',
#   'course',
#   'spirited',
#   'hornpipe',
#   'steal',
#   'recall',
#   'doctor',
#   'shall',
#   'free',
#   'wheeling',
#   'fop'],
#  ['monty',
#   'establish',
#   'patient',
#   'sanity',
#   'take',
#   'month',
#   'change',
#   'thank',
#   'marvin',
#   'monroe',
#   'home',
#   'personality',
#   'test',
#   'simple',
#   'question',
#   'determine',
#   'crazy',
#   'meshuggenah'],
#  ['honey', 'favor', 'fill', 'form'],
#  ['homer', 'intimate', 'psychological', 'profile', 'fill'],
#  ['right', 'right', 'lisa'],
#  ['lisa', 'like', 'homework', 'fill', 'form'],
#  ['right', 'listen', 'poem', 'write'],
#  ['meditation',
#   'turn',
#   'lisa',
#   'simpson',
#   'cat',
#   'name',
#   'snowball',
#   'die',
#   'die',
#   'mom',
#   'say',
#   'sleep',
#   'lie',
#   'lie',
#   'oh',
#   'cat',
#   'dead',
#   'chrysler',
#   'hit',
#   'instead',
#   'hamster',
#   'name',
#   'snuffy',
#   'die'],
#  ['son', 'different', 'time', 'let', 'vote', 'remember', 'absentee', 'ballot'],
#  ['home', 'video', 'finalist', 'man', 'break', 'hip'],
#  ['dog', 'fire', 'ruff', 'anybody', 'order', 'hot', 'dog'],
#  ['finally', 'baby', 'nail', 'gun'],
#  ['okay', 'time', 'cast', 'vote'],
#  ['dog', 'fire', 'dog', 'fire'],
#  ['hey', 'dad', 'hear', 'voice'],
#  ['yes', 'hear', 'right', 'try', 'watch', 'tv'],
#  ['yes', 'quick', 'anger'],
#  ['bart', 'shut', 'shut'],
#  ['yes', 'wet', 'pant', 'good', 'occasional', 'accident'],
#  ['careful', 'man', 'wet', 'pant'],
#  ['devil', 'fly', 'open'],
#  ['spill', 'floor', 'bug', 'go', 'go', 'to', 'eat'],
#  ['happy', 'birthday', 'lisa'],
#  ['boy', 'fair', 'tell', 'sane', 'insane'],
#  ['stamp', 'hand', 'insane'],
#  ['big', 'white', 'guy', 'think', 'little', 'black', 'guy'],
#  ['hi', 'michael', 'jackson', 'jackson'],
#  ['homer', 'simpson', 'simpson'],
#  ['believe', 'hear', 'popular', 'entertainer'],
#  ['oh', 'course', 'hear', 'mean', 'live', 'rock', 'know'],
#  ['billie', 'jean', 'lover', 'girl', 'say', 'kid', 'son', 'hee', 'hee', 'hee'],
#  ['wow', 'thing', 'foot'],
#  ['look', 'raise', 'heel', 'bit', 'little', 'pressure', 'ball', 'foot'],
#  ['hee', 'hee', 'hee'],
#  ['like', 'nice', 'guy'],
#  ['wear', 'pink', 'shirt'],
#  ['understand', 'people', 'think', 'crazy', 'way', 'dress'],
#  ['white', 'glove', 'cover', 'rhinestone'],
#  ['bbl', 'bbl', 'bbl', 'bbl'],
#  ['bart',
#   'split',
#   'second',
#   'die',
#   'bet',
#   'scratchy',
#   'appreciate',
#   'birthday',
#   'present',
#   'relate'],
#  ['hey', 'want', 'year', 'gesture', 'get', 'sis'],
#  ['hey', 'michael', 'guy', 'normal'],
#  ['homer', 'floyd', 'idiot', 'savant', 'number', 'multiply', 'head', 'like'],
#  ['guy', 'chief', 'say', 'word', 'move', 'muscle'],
#  ['time', 'somebody', 'reach'],
#  ['gee', 'got', 'to', 'family'],
#  ['oh',
#   'embarrassing',
#   'call',
#   '-PRON-',
#   'nut',
#   'house',
#   'mean',
#   'think',
#   'god'],
#  ['oh',
#   'great',
#   'uh',
#   'try',
#   'good',
#   'face',
#   'tell',
#   'place',
#   'rich',
#   'woman',
#   'lose',
#   'weight'],
#  ['joe', 'crematorium', 'kill', '-PRON-', 'grill', '-PRON-'],
#  ['bart', 'simpson', 'hell'],
#  ['michael', 'jackson', 'way'],
#  ['true', 'father', 'mental', 'institution'],
#  ['uh', 'huh', 'elvis'],
#  ['aw', 'come', 'michael', 'jackson', 'date', 'grammys'],
#  ['brooke', 'shields', 'diana', 'ross', 'emmanuel', 'lewis', 'bubble'],
#  ['shiver',
#   'timber',
#   'michael',
#   'jackson',
#   'stay',
#   'line',
#   'friend',
#   'relative'],
#  ['afraid', 'bart', 'father', 'need', 'help', 'want', 'lobotomy'],
#  ['probably',
#   'size',
#   'uh',
#   'huh',
#   'new',
#   'bedlam',
#   'asylum',
#   'love',
#   'need',
#   'fear',
#   'get',
#   'michael',
#   'jackson',
#   'whoo',
#   'hoo',
#   'love',
#   'man'],
#  ['hey', 'mom', 'dad', 'mental', 'institution'],
#  ['oh', 'god', 'mother', 'right'],
#  ['homer', 'worry', 'family', 'go', 'to', 'know'],
#  ['forget', 'pal', 'way', 'be', 'pretty'],
#  ['tell', 'kid', 'go', 'send', 'father', 'crazy', 'house'],
#  ['mom', 'say', 'poor', 'house'],
#  ['say', 'crazy', 'house'],
#  ['hello',
#   'reach',
#   'new',
#   'bedlam',
#   'wrongly',
#   'commit',
#   'hotline',
#   'operator',
#   'currently',
#   'busy',
#   'stay',
#   'line'],
#  ['place', 'strange', 'mike', 'ashamed', 'admit', 'guy', 'scared'],
#  ['scared', 'maybe', 'help'],
#  ['homer', 'nee', 'look', 'find', 'look', 'friend', 'friend', 'get', 'friend'],
#  ['pancakes', 'football', 'booby'],
#  ['bubble', 'go', 'to', 'long', 'night'],
#  ['wish', 'love', 'good', 'wish', 'peace', 'joy'],
#  ['feel',
#   'free',
#   'express',
#   'session',
#   'want',
#   'feel',
#   'relaxed',
#   'uninhibited'],
#  ['okay',
#   'work',
#   'insurance',
#   'company',
#   'right',
#   'huh',
#   'youngest',
#   'vp',
#   'history',
#   'firm',
#   'okay',
#   'job',
#   'life',
#   'monday',
#   'morning',
#   'get',
#   'leave',
#   'house'],
#  ['homer',
#   'dave',
#   'suffer',
#   'agoraphobia',
#   'fear',
#   'open',
#   'area',
#   'crowd',
#   'dave'],
#  ['thank', 'day', 'know', 'long', 'drive', 'work'],
#  ['mrs',
#   'simpson',
#   'sorry',
#   'husband',
#   'suffer',
#   'persecution',
#   'complex',
#   'extreme',
#   'paranoia',
#   'bladder',
#   'hostility'],
#  ['doctor', 'talk', 'minute', 'mention', 'son', 'bart', 'sane'],
#  ['mean', 'bart', 'good', 'lord'],
#  ['oh', 'mr', 'simpson', 'get', 'visitor'],
#  ['mr', 'simpson', 'talk', 'wife', 'believe', 'threat'],
#  ['flattering', 'thing', 'say', 'writing'],
#  ['thank', 'lot', 'michael', 'help', 'find', 'marble', 'come', 'visit'],
#  ['get',
#   'real',
#   'depressed',
#   'wall',
#   'album',
#   'get',
#   'lousy',
#   'grammy',
#   'nomination'],
#  ['happy',
#   'birthday',
#   'happy',
#   'birthday',
#   'happy',
#   'birthday',
#   'overlook',
#   'middle',
#   'child',
#   'happy',
#   'birthday'],
#  ['joe', 'taxidermy', 'snuff', '-PRON-', 'stuff', '-PRON-'],
#  ['boy', 'home', 'go', 'wrap', 'hand', 'neck'],
#  ['homer', 'get', 'cut', 'dose'],
#  ['listen',
#   'bring',
#   'michael',
#   'jackson',
#   'home',
#   'stay',
#   'day',
#   'cute',
#   'hear',
#   'sure',
#   'plenty',
#   'cold',
#   'cut',
#   'beer',
#   'ice'],
#  ['um', 'homer', 'vegetarian', 'drink'],
#  ['yes', 'homer', 'sure', 'tell', 'anybody', 'come'],
#  ['yes', 'dad', 'solemnly', 'swear', 'tell', 'live', 'soul', 'milhouse'],
#  ['hello', 'milhouse', 'secret'],
#  ['oh', 'care', 'michael', 'jackson', 'come', 'house'],
#  ['aunt', 'bella', 'wait', 'minute', 'get', 'line', 'michael', 'jackson'],
#  ['hand', 'bulletin', 'rock', "'", 'n', "'", 'rumor', 'department'],
#  ['right',
#   'michael',
#   'jackson',
#   'thriller',
#   'moonwalkin',
#   "'",
#   'way',
#   'right',
#   'spring',
#   'field'],
#  ['check',
#   'enjoy',
#   'seldom',
#   'hear',
#   'extra',
#   'longggg',
#   'version',
#   'gadda',
#   'da',
#   'vida'],
#  ['michael',
#   'jackson',
#   'oh',
#   'thing',
#   'happen',
#   'blue',
#   'moon',
#   'dare',
#   'leave',
#   'post'],
#  ['exciting',
#   'thing',
#   'happen',
#   'fair',
#   'town',
#   'uh',
#   'dalai',
#   'lama',
#   'visit',
#   'declare',
#   'route',
#   'currently',
#   'know',
#   'dalai',
#   'lama',
#   'expressway',
#   'henceforth',
#   'know',
#   'michael',
#   'jackson',
#   'expressway'],
#  ['guy',
#   'pink',
#   'shirt',
#   'father',
#   'family',
#   'turn',
#   'release',
#   'mental',
#   'hospital'],
#  ['thank', 'everybody', 'great', 'sane'],
#  ['hell', 'think', 'michael', 'jackson', 'visit', 'jerkwater', 'burg'],
#  ['owe', 'michael', 'jackson'],
#  ['face', 'ya', 'tool'],
#  ['bart',
#   'entire',
#   'town',
#   'howl',
#   'blood',
#   'join',
#   'question',
#   'today',
#   'birthday',
#   'promise',
#   'afraid',
#   'ask'],
#  ['know', 'maybe', 'trust', 'instinct', 'ask'],
#  ['think', 'oh', 'bart'],
#  ['dear',
#   'bart',
#   'stationery',
#   'mom',
#   'dad',
#   'give',
#   'birthday',
#   'inform',
#   'brother',
#   'sister',
#   'professional',
#   'advise',
#   'hug',
#   'far',
#   'distant',
#   'family',
#   'reunion',
#   'rest',
#   'assure',
#   'purely'],
#  ['wish', 'better', 'heart', 'desire'],
#  ['bart', 'kid', 'money', 'know', 'sister', "'", 'birthday', 'roll'],
#  ['write', 'song', 'care'],
# ...
#   'dong',
#   'sound',
#   'liberty',
#   'bell',
#   'ding',
#   'freedom',
#   'dong',
#   'opportunity',
#   'ding',
#   'excellent',
#   'school',
#   'dong',
#   'quality',
#   'hospital'],
#  ['america',
#   'bear',
#   'hot',
#   'july',
#   'day',
#   'tree',
#   'springfield',
#   'forest',
#   'tiny',
#   'sapling',
#   'tremble',
#   'sun',
#   'nourish',
#   'mother',
#   'earth',
#   'fledgling',
#   'nation',
#   'find',
#   'strength',
#   'simple',
#   'ideal',
#   'equality',
#   'justice',
#   'think',
#   'mighty',
#   'oak',
#   'powerful',
#   'nation',
#   'grow',
#   'fragile',
#   'pure',
#   'thank'],
#  ['good',
#   'little',
#   'good',
#   'year',
#   'old',
#   'methink',
#   'detect',
#   'sickly',
#   'scent',
#   'daddy'],
#  ['mr',
#   'simpson',
#   'like',
#   'ask',
#   'question',
#   'daughter',
#   'essay',
#   'lisa',
#   'excuse'],
#  ['interested', 'politic', 'government'],
#  ['lisa',
#   'meet',
#   'father',
#   'decide',
#   'award',
#   'additional',
#   'point',
#   'congratulation',
#   'family',
#   'go',
#   'washington'],
#  ['woo', 'hoo', 'guess', 'reading', 'writing', 'pay'],
#  ['play',
#   'card',
#   'notepad',
#   'aspirin',
#   'sewing',
#   'kit',
#   'pilot',
#   'wing',
#   'pin',
#   'propellor',
#   'shape',
#   'swizzle',
#   'stick',
#   'sleep',
#   'mask',
#   'get',
#   'come'],
#  ['little', 'boy', 'bet', 'like', 'visit', 'cockpit'],
#  ['control', 'stick', 'like', 'handlebar', 'tricycle', 'like', 'hang', 'coat'],
#  ['thank', 'push', 'button'],
#  ['go', 'to', 'die'],
#  ['look', 'marge', 'guy', 'taxi'],
#  ['oooh', 'look', 'homer', 'irs'],
#  ['homer',
#   'look',
#   'shower',
#   'cap',
#   'body',
#   'gel',
#   'bathrobe',
#   'ooh',
#   'welcome',
#   'mint',
#   'pillow'],
#  ['wowww', 'shoehorn', 'like', 'movie'],
#  ['shoe',
#   'go',
#   'shoe',
#   'go',
#   'shoe',
#   'go',
#   'shoe',
#   'go',
#   'shoe',
#   'go',
#   'shoe',
#   'go'],
#  ['bart', 'thing', 'bedsie'],
#  ['good', 'night', 'sleep', 'lisa'],
#  ['stupid', 'welcome', 'mint', "y'ello"],
#  ['good', 'morning', 'wake'],
#  ['lisa', 'faith', 'crowley', 'patriotism', 'editor', 'read', 'digest'],
#  ['ooh',
#   'love',
#   'magazine',
#   'favorite',
#   'section',
#   'increase',
#   'word',
#   'power',
#   'thing',
#   'good'],
#  ['lisa',
#   'like',
#   'meet',
#   'finalist',
#   'truong',
#   'van',
#   'dinh',
#   'maria',
#   'dominguez'],
#  ['maria',
#   'national',
#   'spelling',
#   'bee',
#   'champion',
#   'truong',
#   'win',
#   'westinghouse',
#   'talent',
#   'search',
#   'nfl',
#   'punt',
#   'pass',
#   'kick',
#   'competition'],
#  ['run', 'problem', 'superior', 'ability'],
#  ['special', 'vip', 'badge', 'place', 'tourist'],
#  ['spot', 'richard', 'nixon', 'bowl', 'game'],
#  ['wow', 'president', 'bathroom'],
#  ['oh', 'damn', 'badge', 'okay', 'tub', 'instal'],
#  ['hey', 'watch', 'chief'],
#  ['folk',
#   'print',
#   'eighteen',
#   'million',
#   'bill',
#   'day',
#   'oh',
#   'case',
#   'wonder',
#   'free',
#   'sample'],
#  ['lousy', 'cheap', 'country'],
#  ['bart', 'spirit', 'st', 'louis'],
#  ['oh', 'marge', 'grow'],
#  ['congressman', 'springfield', 'national', 'forest'],
#  ['basically', 'want', 'cut'],
#  ['artist',
#   'rendition',
#   'old',
#   'growth',
#   'age',
#   'fester',
#   'away',
#   'come',
#   'log',
#   'company',
#   'thin',
#   'clutter',
#   'nature',
#   "y'know",
#   'cycle'],
#  ['jerry',
#   'whale',
#   'lobbyist',
#   'like',
#   'logging',
#   'permit',
#   'uh',
#   'like',
#   'bury',
#   'toxic',
#   'waste',
#   'people',
#   'go',
#   'to',
#   'notice',
#   'tree',
#   'go'],
#  ['uh', 'congressman', 'get', 'awkward', 'know', 'want'],
#  ['offer', 'bribe'],
#  ['little', 'girl', 'springfield', 'write', 'essay', 'good', 'photo', 'op'],
#  ['uh', 'sure', 'fine'],
#  ['get', 'little', 'place', 'use', 'uh', 'matter', 'tonight'],
#  ['hi', 'lisa', 'simpson'],
#  ['lisa',
#   'doer',
#   'know',
#   'maybe',
#   'day',
#   'congressman',
#   'senator',
#   'woman',
#   'senator',
#   'know'],
#  ['tot', 'shot', 'play', 'stick'],
#  ['ah', 'nice', 'politician', 'care'],
#  ['lisa', 'contest', 'hour'],
#  ['excited', 'sleep', 'winifre', 'beecher', 'howe', 'memorial'],
#  ['early',
#   'crusader',
#   'woman',
#   'right',
#   'lead',
#   'floormop',
#   'rebellion',
#   'later',
#   'appear',
#   'highly',
#   'unpopular',
#   'cent',
#   'piece'],
#  ['okay', 'know', 'miss'],
#  ['iron', 'sheet', 'iron', 'inequity', 'labor', 'law', 'amen', 'sister'],
#  ['bob', 'stand', 'springfield', 'forest', 'logging', 'permit'],
#  ['let', 'way', 'jerry', 'tim', 'berrr'],
#  ['read', 'essay', 'believe', 'word'],
#  ['honest', 'abe', 'way'],
#  ['mr', 'lincoln', 'need', 'advice', 'well', 'country'],
#  ['good', 'time', 'buy', 'house'],
#  ['boy', 'brush', 'proper'],
#  ['look', 'good', 'moustache'],
#  ['try', 'usin', "'", 'turpentine', 'jes', "'", 'bad'],
#  ['mr', 'lincoln', 'lisa', 'simpson', 'problem'],
#  ['mr', 'jefferson', 'lisa', 'simpson', 'problem'],
#  ['know', 'problem', 'lincoln', 'memorial', 'crowded'],
#  ['come',
#   'blame',
#   'important',
#   'declaration',
#   'independence',
#   'louisiana',
#   'purchase',
#   'dumbwaiter'],
#  ['uh', 'maybe', 'go', 'catch', 'bad', 'time'],
#  ['rudy', 'man', 'miracle', 'worker'],
#  ['bart', 'ready', 'room', 'service'],
#  ['kill', 'remember', 'trip', 'expense', 'pay'],
#  ['deficit',
#   'rag',
#   'oh',
#   'yeah',
#   'deficit',
#   'rag',
#   'budget',
#   'gap',
#   'digit',
#   'drag',
#   'tellin',
#   "'",
#   'ya',
#   'deficit',
#   'mess',
#   'deficit',
#   'ra',
#   'g',
#   'thank'],
#  ['oh', 'guy', 'awful'],
#  ['know', 'honey', 'sit'],
#  ['welcome',
#   'award',
#   'luncheon',
#   'like',
#   'introduce',
#   'distinguished',
#   'judge',
#   'select',
#   'scholarship',
#   'winner'],
#  ['redskin',
#   'great',
#   'alonzo',
#   'flower',
#   'perennial',
#   'party',
#   'candidate',
#   'wilson',
#   'defarge',
#   'senate',
#   'page',
#   'brad',
#   'fletcher',
#   'skin',
#   'care',
#   'consultant',
#   'rowena',
#   'wealthy',
#   'gadabout',
#   'chilton',
#   'gaines'],
#  ['essayist', 'lisa', 'simpson', 'lisa', 'lisa'],
#  ['oh', 'lisa', 'simpson', 'read', 'essay'],
#  ['like', 'read', 'different', 'essay'],
#  ['city',
#   'washington',
#   'build',
#   'stagnant',
#   'swamp',
#   'year',
#   'ago',
#   'little',
#   'change',
#   'stank',
#   'stink',
#   'today',
#   'fetid',
#   'stench',
#   'corruption',
#   'hang',
#   'air'],
#  ['take',
#   'bribe',
#   'honorable',
#   'bob',
#   'arnold',
#   'worry',
#   'congressman',
#   'sure',
#   'buy',
#   'vote',
#   'need',
#   'dirty',
#   'money',
#   'nation',
#   'dollar',
#   'liberty',
#   'justice'],
#  ['senator', 'problem', 'essay', 'contest'],
#  ['little', 'girl', 'lose', 'faith', 'democracy'],
#  ['congressman', 'want', 'drill', 'oil', 'teddy', 'roosevelt', 'head'],
#  ['work', 'uncle', 'sam'],
#  ['vote', 'house', 'bill', 'expulsion', 'bob', 'arnold'],
#  ['mr', 'speaker', 'bill', 'tack', 'pay', 'raise'],
#  ['okay', 'boss', 'happy'],
#  ['family',
#   'arrive',
#   'country',
#   'month',
#   'ago',
#   'speak',
#   'english',
#   'money',
#   'pocket',
#   'today',
#   'nationwide',
#   'chain',
#   'wheel',
#   'balancing',
#   'center',
#   'america',
#   'possibly',
#   'canada',
#   'family',
#   'find',
#   'opportunity',
#   'star',
#   'stripes',
#   'remind',
#   'wonderful',
#   'word',
#   'flag'],
#  ['brief', 'recess', 'judge', 'tabulate', 'vote'],
#  ['yeah', 'speech', 'little', 'crowd', 'pleasin', "'"],
#  ['sorry', 'dad', 'think', 'nice', 'way', 'america', 'stink'],
#  ['extra', 'extra', 'fed', 'nab', 'rotten', 'rep'],
#  ['imprison', 'congressman', 'bear', 'christian'],
#  ['believe', 'system', 'work'],
#  ['trading',
#   'gap',
#   'shuffle',
#   'heap',
#   'trouble',
#   'do',
#   'trading',
#   'gap',
#   'shuffle',
#   'yes',
#   'sir'],
#  ['budget', 'gap', 'trading', 'gap'],
#  ['moment',
#   'truth',
#   'winning',
#   'essay',
#   'bubble',
#   'o',
#   'melt',
#   'pot',
#   'lift',
#   'high',
#   'lamp',
#   'green',
#   'lady',
#   'usa',
#   'o',
#   'k',
#   'cesspool',
#   'potomac'],
#  ['cesspool', 'cesspool', 'cesspool', 'cesspool', 'cesspool'],
#  ['winner', 'usa', 'o', 'k', 'truong', 'van', 'dinh'],
#  ['miss',
#   'crowley',
#   'thank',
#   'sized',
#   'novelty',
#   'check',
#   'like',
#   'share',
#   'honor',
#   'fellow',
#   'essayist',
#   'particularly',
#   'courageous',
#   'lisa',
#   'simpson',
#   'inflammatory',
#   'rhetoric',
#   'remind',
#   'price',
#   'freedom',
#   'eternal',
#   'vigilance'],
#  ['let',
#   'tell',
#   'lisa',
#   's',
#   'little',
#   'year',
#   'old',
#   'muckraker',
#   'ess',
#   'catch',
#   'crook',
#   'pay',
#   'day',
#   'ball'],
#  ['lis', 'teach', 'stand', 'believe'],
#  ['homer', 'silly', 'goose', 'weed', 'whacker', 'edge', 'go', 'to', 'day'],
#  ['picture',
#   'half',
#   'hee',
#   'hee',
#   'finish',
#   'tomorrow',
#   'come',
#   'strap',
#   'feed',
#   'bag',
#   'go',
#   'to',
#   'fire',
#   'old',
#   'propane',
#   'elaine',
#   'heat',
#   'meat',
#   'nummy',
#   'nummy',
#   'num'],
#  ['flander',
#   'have',
#   'beef',
#   'thon',
#   'incredible',
#   'ned',
#   'ible',
#   'maude',
#   'acious',
#   'vittle'],
#  ['think', 'mean', 'have', 'barbecue'],
#  ['try', 'friendly', 'know', 'give', 'ne', 'flander', 'chance'],
#  ['oh',
#   'look',
#   'care',
#   'ned',
#   'flander',
#   'nice',
#   'guy',
#   'world',
#   'jerk',
#   'end',
#   'story'],
#  ['hold', 'thing', 'little', 'well'],
#  ['excuse', 'well', 'thank', 'lot', 'marge', 'place'],
#  ['wrong',
#   'worth',
#   'feel',
#   'inch',
#   'tall',
#   'find',
#   'kind',
#   'person',
#   'marge',
#   'simpson',
#   'president',
#   'international',
#   'love',
#   'flander',
#   'fan',
#   'club'],
#  ['fee',
#   'fi',
#   'fo',
#   'fum',
#   'smell',
#   'potato',
#   'au',
#   'gratin',
#   'marge',
#   'simp',
#   'son',
#   'mmmm',
#   'mmm'],
#  ['hi',
#   'ned',
#   'homer',
#   'send',
#   'apology',
#   'uh',
#   'important',
#   'work',
#   'plant',
#   'care'],
#  ['return',
#   'exciting',
#   'fifteenth',
#   'round',
#   'action',
#   'canadian',
#   'football',
#   'league',
#   'draft'],
#  ['saskatchewan',
#   'rough',
#   'rider',
#   'score',
#   'rouge',
#   'season',
#   'jack',
#   'kicker',
#   'sorely',
#   'need'],
#  ['stupid',
#   'flander',
#   'show',
#   'ahead',
#   'marge',
#   'ball',
#   'game',
#   'dead',
#   'eat',
#   'cry',
#   'eye',
#   'go',
#   'flander',
#   "'",
#   'oh',
#   'flander',
#   "'",
#   'house',
#   'leave',
#   'homer',
#   'food',
#   'laugh',
#   'laugh',
#   'grave'],
#  ['boy', 'mmmmmmmm', 'bar', 'b', 'que'],
#  ['hey', 'great', 'ya', 'nice', 'seein', "'", 'ya'],
#  ['okay', 'thank', 'comin', "'"],
#  ['electricity', 'electricity', 'freeze', 'tag'],
#  ['lie', 'like', 'fly', 'booger', 'eye'],
#  ['fly', 'funny', 'booger', 'icing', 'cake'],
#  ['friend',
#   'love',
#   'sinister',
#   'motive',
#   'ask',
#   'sinister',
#   'latin',
#   'left',
#   'handed',
#   'joking'],
#  ['friday', 'say', 'toodle', 'oo', 'pharmaceutical', 'game'],
#  ['kid', 'noose', 'wear', 'year'],
#  ['sir',
#   'like',
#   'americans',
#   'leave',
#   'handed',
#   'let',
#   'tell',
#   'be',
#   'peach',
#   'cream',
#   'writing',
#   'get',
#   'smear',
#   'lord',
#   'help',
#   'want',
#   'drive',
#   'standard',
#   'transmission'],
#  ['sir',
#   'open',
#   'stop',
#   'store',
#   'southpaw',
#   'left',
#   'handed',
#   'apple',
#   'peeler',
#   'leave',
#   'handed',
#   'zither',
#   'go',
#   'to',
#   'leftorium'],
#  ['homer', 'dyin', "'", 'know', 'think', 'leftorium'],
#  ['uh', 'sound', 'like', 'pretty', 'dumb', 'idea'],
#  ['know',
#   'little',
#   'risky',
#   'go',
#   'to',
#   'lot',
#   'hard',
#   'work',
#   'gosh',
#   'darn',
#   'go',
#   'to',
#   'lot',
#   'fun'],
#  ['fun', 'store', 'flander', 'merry', 'old', 'land', 'oz'],
#  ['oh', 'springfield', 'mall'],
#  ['want', 'wish', 'homer'],
#  ['come', 'homer', 'get', 'ambition', 'wishin', "'"],
#  ['pant', 'flander', 'wish', 'fast'],
#  ['yesssss', 'oh', 'yessss', 'read', 'weep', 'face', 'get', 'chicken', 'bone'],
#  ['will', 'come', 'true'],
#  ['bart', 'hour', 'day', 'watch', 'tv'],
#  ['think', 'little', 'fresh', 'air', 'maybe', 'exercise'],
#  ['yeah', 'ya', 'go', 'to'],
#  ['marge', 'tv', 'give', 'ask', 'little', 'boy', 'good', 'friend'],
#  ['problem',
#   'speak',
#   'million',
#   'child',
#   'stare',
#   'tv',
#   'instead',
#   'get',
#   'need',
#   'exercise',
#   'child',
#   'parent',
#   'ashamed'],
#  ['hello', 'akira', 'ha'],
#  ['hurt', 'know', 'ancient', 'art', 'karate'],
#  ['karate', 'focus', 'mind', 'give', 'self', 'confidence'],
#  ['people', 'walk', 'life', 'doctor'],
#  ['landscape', 'architect'],
#  ['high', 'karate', 'low', 'low', 'price'],
#  ['tell', 'lie', 'great', 'deal'],
#  ['hey', 'mom', 'about', 'learn', 'karate', 'happy'],
#  ['sound', 'fine', 'bart'],
#  ['marge',
#   'knock',
#   'tv',
#   'help',
#   'think',
#   'owe',
#   'somebody',
#   'little',
#   'apology'],
#  ['ow', 'ow', 'ow', 'ow'],
#  ['hey', 'flander', 'business'],
#  ['oh', 'little', 'pokey', 'thing', 'go', 'to', 'pick'],
#  ['money', 'away', 'accident'],
#  ['thank', 'validate', 'parking'],
#  ['n',
#   'mall',
#   'security',
#   'guard',
#   'take',
#   'good',
#   'long',
#   'look',
#   'left',
#   'handed',
#   'ice',
#   'cream',
#   'scoop'],
#  ['greeting',
#   'akira',
#   'guide',
#   'path',
#   'true',
#   'karate',
#   'map',
#   'art',
#   'war',
#   'sun',
#   'tzu',
#   'teach',
#   'important',
#   'lesson',
#   'learn',
#   'karate',
#   'need',
#   'use'],
#  ['um', 'excuse', 'sir', 'know', 'hit', 'guy', 'break', 'nunchuck'],
#  ['ah', 'yes', 'impetuousness', 'youth', 'let', 'read'],
#  ['akira', 'good', 'man', 'break', 'block', 'ice', 'head'],
#  ['fill', 'head', 'wisdom', 'hit', 'ice'],
#  ['yo', 'sensei', 'bathroom'],
#  ['pay', 'money', 'read', 'book', 'hell'],
#  ['come', 'touch', 'death', 'touch', 'death', 'touch', 'death'],
#  ['tell',
#   'flander',
#   "'",
#   'store',
#   'dee',
#   'serte',
#   'think',
#   'best',
#   'buddy',
#   'marge'],
#  ['dad', 'know', 'schadenfreude'],
#  ['know', 'schadenfreude', 'tell', 'die', 'know'],
#  ['german', 'term', 'shameful', 'joy', 'take', 'pleasure', 'suffering'],
#  ['oh',
#   'come',
#   'lisa',
#   'glad',
#   'fall',
#   'flat',
#   'butt',
#   'usually',
#   'happy',
#   'comfortable',
#   'surround',
#   'love',
#   'one',
#   'make',
#   'feel',
#   'opposite',
#   'shameful',
#   'joy',
#   'thing'],
#  ['boy', 'germans', 'word'],
#  ['bart', 'learn', 'karate', 'school', 'today'],
#  ['yeah', 'come', 'boy', 'well', 'worth', 'buck'],
#  ['uh', 'learn', 'touch', 'death'],
#  ['ooh', 'touch', 'death'],
#  ['permit', 'demonstrate', 'lisa', 'shut', 'eye', 'soon', 'peace'],
#  ['hey',
#   'quit',
#   'bart',
#   'quit',
#   'hey',
#   'quit',
#   'quit',
#   'quit',
#   'm',
#   'o',
#   'o',
#   'o',
#   'm'],
#  ['bart', 'use', 'touch', 'death', 'sister'],
#  ['uh', 'oh', 'get', 'to', 'karate', 'class'],
#  ['right', 'comin', "'", 'outta', 'way', 'step', 'aside', 'lady'],
#  ['hey', 'boy', 'class'],
#  ['today', 'learn', 'rip', 'man', 'heart', 'die'],
#  ['oh', 'learn', "'", 'be'],
#  ['love', 'lefty', 'shoot', 'glass'],
#  ['left', 'handed', 'pink', 'shear'],
#  ['pink', 'shear', 'let', 'food', 'court', 'steal', 'bake', 'potato'],
#  ['hey', 'flander', 'busy', 'hour'],
#  ['oh',
#   'oh',
#   'oh',
#   'expect',
#   'thing',
#   'start',
#   'pick',
#   'soon',
#   'think',
#   'word',
#   'mouth',
#   'startin',
#   "'",
#   'spread'],
#  ['hey', 'hear', 'validate', 'parking', 'ticket', 'purchase'],
#  ['oh', 'right', 'rain', 'leave', 'rain'],
#  ['hey', 'homer', 'neighbor', 'store'],
#  ['lousy', 'sit', 'day', 'great', 'job', 'place'],
#  ['crummy', 'right', 'handed', 'corkscrews', 'sell'],
#  ['uh', 'actually', 'moe'],
#  ['hey', 'lis', 'change', 'channel'],
#  ['grow', 'weary', 'new', 'channel', 'change'],
#  ['apple',
#   'apple',
#   'apple',
#   'come',
#   'candy',
#   'bar',
#   'hey',
#   'know',
#   'apple',
#   'want',
#   'sink',
#   'go',
#   'to',
#   'let',
#   '-PRON-',
#   'time'],
#  ['simpson', 'box', 'mr', 'burns', "'", 'desk', 'chop', 'chop'],
#  ['ah',
#   'look',
#   'smither',
#   'member',
#   'nuclear',
#   'family',
#   'helpful',
#   'suggestion'],
#  ['simpson', 'eh', 'hmm', 'hmmm', 'monty', 'burn'],
#  ['hm',
#   'handsome',
#   'owner',
#   'sight',
#   'distract',
#   'female',
#   'employee',
#   'smither'],
#  ['oh', 'real', 'apple', 'vend', 'machine', 'sentence'],
#  ['leave', 'mr', 'burns'],
#  ['oh', 'course', 'worry', 'plenty', 'apple', 'away', 'precious', 'apple'],
#  ['tell', 'secretary', 'say', 'free', 'apple', 'right', 'promise'],
#  ['damned', 'infernal', 'gizmo', 'kingdom', 'left', 'handed', 'opener'],
#  ['um', 'mr', 'burns'],
#  ['come', 'homer', 'tell', 'store', 'dyin', "'"],
#  ['sure', 'interest', 'dollar', 'asking', 'price'],
#  ['hey', 'flexible', 'pay', 'night', 'change', 'mind'],
#  ['hey', 'flander', 'okay'],
#  ['oh', 'yeah', 'sure', 'think', 'rid', 'clutter', 'like'],
#  ['oh', 'good', 'good', 'catch', 'dead', 'buy', 'hello'],
#  ['ah', 'get', 'eye', 'gas', 'grill', 'butane', 'beaut'],
#  ['homer', 'pay', 'dollar', 'year'],
#  ['swindle', 'friend', 'buck', 'leave'],
#  ['oh', 'homer', 'reasonable'],
#  ['sorry',
#   'cash',
#   'neddie',
#   'homer',
#   'money',
#   'bye',
#   'bye',
#   'neddie',
#   'bye',
#   'bye'],
#  ['change',
#   'mind',
#   'pass',
#   'fancy',
#   'throw',
#   'lawn',
#   'chair',
#   'maybe',
#   'tool',
#   'bench',
#   'rekindle',
#   'interest'],
#  ...]

# %% [markdown]
# Cria as frases relevantes da lista de frases:

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000) #Crio uma lista de palavras para poder aplicar o bigrama
# Out:
# INFO - 15:15:59: collecting all words and their counts
# INFO - 15:15:59: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 15:15:59: PROGRESS: at sentence #10000, processed 63561 words and 52816 word types
# INFO - 15:15:59: PROGRESS: at sentence #20000, processed 130943 words and 99866 word types
# INFO - 15:15:59: PROGRESS: at sentence #30000, processed 192972 words and 138532 word types
# INFO - 15:15:59: PROGRESS: at sentence #40000, processed 249842 words and 172659 word types
# INFO - 15:15:59: PROGRESS: at sentence #50000, processed 311265 words and 208566 word types
# INFO - 15:16:00: PROGRESS: at sentence #60000, processed 373588 words and 243702 word types
# INFO - 15:16:00: PROGRESS: at sentence #70000, processed 436441 words and 278740 word types
# INFO - 15:16:00: PROGRESS: at sentence #80000, processed 497829 words and 311886 word types
# INFO - 15:16:00: collected 330804 word types from a corpus of 537160 words (unigram + bigrams) and 85964 sentences
# INFO - 15:16:00: using 330804 counts as vocab in Phrases<0 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>

# %%
bigram = Phraser(phrases) #Para relacionar vetores a dupla de plavras Barn Simpson, Homer Simpson...
# Out:
# INFO - 15:16:18: source_vocab length 330804
# INFO - 15:16:21: Phraser built with 126 phrasegrams

# %% [markdown]
# Transforme o corpus com base nos bigramas detectados:

# %%
sentences = bigram[sent]

# %% [markdown]
# ##Palavras mais frequentes:
# Principalmente uma verificação de integridade da eficácia da lematização, remoção de palavras irrelevantes e adição de bigramas.

# %%
#Verificar as palavras mais frequentes
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 30178

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:15] #As 15 palavras mais frequentes
# Out:
# ['oh',
#  'like',
#  'know',
#  'get',
#  'hey',
#  'think',
#  'right',
#  'look',
#  'want',
#  'come',
#  'homer',
#  'let',
#  'good',
#  "'",
#  'go']

# %% [markdown]
# # Treinar o modelo
# ## Implementação Gensim Word2Vec:
# Usamos a implementação Gensim de word2vec: https://radimrehurek.com/gensim/models/word2vec.html

# %%
import multiprocessing

from gensim.models import Word2Vec

# %% [markdown]
# ## Por que separo o treinamento do modelo em 3 etapas:
# Prefiro separar o treinamento em 3 etapas distintas para maior clareza e monitoramento.
# 1. `Word2Vec ()`:
# > Nesta primeira etapa, configurei os parâmetros do modelo um por um. <br> Eu não forneço o parâmetro `sentenças` e, portanto, deixo o modelo não inicializado, propositalmente.
# 2. `.build_vocab ()`:
# > Aqui, ele constrói o vocabulário a partir de uma sequência de frases e, assim, inicializa o modelo. <br> Com os registros, posso acompanhar o progresso e, mais importante ainda, o efeito de `min_count` e` sample` no corpus de palavras. Percebi que esses dois parâmetros, e em particular `sample`, têm uma grande influência sobre o desempenho de um modelo. Exibir ambos permite um gerenciamento mais preciso e fácil de sua influência.
# 3. `.train ()`:
# > Finalmente, treina o modelo. <br>
# Os registros aqui são principalmente úteis para monitoramento, certificando-se de que nenhuma thread seja executada instantaneamente.

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer

# %% [markdown]
# # Os parametros:
#
# * `min_count` <font color = 'purple'> = </font> <font color = 'green'> int </font> - Ignora todas as palavras com frequência absoluta total inferior a esta - (2, 100)
#
#
# * `window` <font color = 'purple'> = </font> <font color = 'green'> int </font> - A distância máxima entre a palavra atual e a prevista em uma frase. Por exemplo. palavras `janela` à esquerda e palavras` janela` à esquerda do nosso alvo - (2, 10)
#
#
# * `size` <font color = 'purple'> = </font> <font color = 'green'> int </font> - Dimensionalidade dos vetores de recursos. - (50, 300)
#
#
# * `sample` <font color = 'purple'> = </font> <font color = 'green'> float </font> - O limite para configurar quais palavras de alta frequência são reduzidas aleatoriamente. Altamente influente. - (0, 1e-5)
#
#
# * `alpha` <font color = 'purple'> = </font> <font color = 'green'> float </font> - A taxa de aprendizagem inicial - (0,01, 0,05)
#
#
# * `min_alpha` <font color = 'purple'> = </font> <font color = 'green'> float </font> - A taxa de aprendizagem cairá linearmente para` min_alpha` conforme o treinamento progride. Para defini-lo: alpha - (min_alpha * epochs) ~ 0,00
#
#
# * `negative` <font color = 'purple'> = </font> <font color = 'green'> int </font> - Se> 0, a amostragem negativa será usada, o int para negativo especifica quantos" ruído palavras "deve ser afogada. Se definido como 0, nenhuma amostra negativa é usada. - (5, 20)
#
#
# * `workers` <font color = 'purple'> = </font> <font color = 'green'> int </font> - Use esses vários threads de trabalho para treinar o modelo (= treinamento mais rápido com máquinas multicore)

# %%
w2v_model = Word2Vec(min_count=20, #palavras que aparecem menos de 20 vezes não interessam
                     window=2,     #Palavras para janelar, utilizadas para prever
                     size=300,     #Dimensão do vetor
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %% [markdown]
# ## Construindo a Tabela de Vocabulário:
# O Word2Vec exige que construamos a tabela de vocabulário (simplesmente digerindo todas as palavras e filtrando as palavras únicas e fazendo algumas contagens básicas com elas):

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 15:28:58: collecting all words and their counts
# INFO - 15:28:58: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 15:28:58: PROGRESS: at sentence #10000, processed 61718 words, keeping 9558 word types
# INFO - 15:28:58: PROGRESS: at sentence #20000, processed 127351 words, keeping 14506 word types
# INFO - 15:28:58: PROGRESS: at sentence #30000, processed 187829 words, keeping 17619 word types
# INFO - 15:28:59: PROGRESS: at sentence #40000, processed 243332 words, keeping 20385 word types
# INFO - 15:28:59: PROGRESS: at sentence #50000, processed 303182 words, keeping 22878 word types
# INFO - 15:28:59: PROGRESS: at sentence #60000, processed 363940 words, keeping 25200 word types
# INFO - 15:28:59: PROGRESS: at sentence #70000, processed 425408 words, keeping 27401 word types
# INFO - 15:29:00: PROGRESS: at sentence #80000, processed 485464 words, keeping 29275 word types
# INFO - 15:29:00: collected 30178 word types from a corpus of 523700 raw words and 85964 sentences
# INFO - 15:29:00: Loading a fresh vocabulary
# INFO - 15:29:00: effective_min_count=20 retains 3319 unique words (10% of original 30178, drops 26859)
# INFO - 15:29:00: effective_min_count=20 leaves 437324 word corpus (83% of original 523700, drops 86376)
# INFO - 15:29:00: deleting the raw counts dictionary of 30178 items
# INFO - 15:29:00: sample=6e-05 downsamples 1200 most-common words
# INFO - 15:29:00: downsampling leaves estimated 199161 word corpus (45.5% of prior 437324)
# INFO - 15:29:00: estimated required memory for 3319 words and 300 dimensions: 9625100 bytes
# INFO - 15:29:00: resetting layer weights
# Time to build vocab: 0.04 mins

# %% [markdown]
# ## Treinamento do modelo:
# _Parâmetros do treinamento: _
# * `total_examples` <font color = 'purple'> = </font> <font color = 'green'> int </font> - Contagem de frases;
# * `epochs` <font color = 'purple'> = </font> <font color = 'green'> int </font> - Número de iterações (épocas) no corpus - [10, 20, 30]

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 15:29:12: training model with 1 workers on 3319 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2
# INFO - 15:29:13: EPOCH 1 - PROGRESS: at 33.37% examples, 64208 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:14: EPOCH 1 - PROGRESS: at 67.17% examples, 62964 words/s, in_qsize 1, out_qsize 0
# INFO - 15:29:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:15: EPOCH - 1 : training on 523700 raw words (198820 effective words) took 3.0s, 65202 effective words/s
# INFO - 15:29:16: EPOCH 2 - PROGRESS: at 33.37% examples, 67466 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:17: EPOCH 2 - PROGRESS: at 69.05% examples, 66952 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:18: EPOCH - 2 : training on 523700 raw words (199218 effective words) took 2.9s, 68159 effective words/s
# INFO - 15:29:19: EPOCH 3 - PROGRESS: at 33.37% examples, 66354 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:20: EPOCH 3 - PROGRESS: at 70.95% examples, 67369 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:21: EPOCH - 3 : training on 523700 raw words (199222 effective words) took 2.9s, 68213 effective words/s
# INFO - 15:29:22: EPOCH 4 - PROGRESS: at 33.37% examples, 66375 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:23: EPOCH 4 - PROGRESS: at 67.17% examples, 64789 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:24: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:24: EPOCH - 4 : training on 523700 raw words (199150 effective words) took 3.0s, 66553 effective words/s
# INFO - 15:29:25: EPOCH 5 - PROGRESS: at 33.37% examples, 66739 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:26: EPOCH 5 - PROGRESS: at 69.05% examples, 67177 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:27: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:27: EPOCH - 5 : training on 523700 raw words (199540 effective words) took 2.9s, 68045 effective words/s
# INFO - 15:29:28: EPOCH 6 - PROGRESS: at 33.37% examples, 66394 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:29: EPOCH 6 - PROGRESS: at 70.95% examples, 67733 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:30: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:30: EPOCH - 6 : training on 523700 raw words (199462 effective words) took 2.9s, 68463 effective words/s
# INFO - 15:29:31: EPOCH 7 - PROGRESS: at 33.37% examples, 65934 words/s, in_qsize 1, out_qsize 0
# INFO - 15:29:32: EPOCH 7 - PROGRESS: at 67.17% examples, 63850 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:33: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:33: EPOCH - 7 : training on 523700 raw words (199000 effective words) took 3.0s, 65736 effective words/s
# INFO - 15:29:34: EPOCH 8 - PROGRESS: at 33.37% examples, 65977 words/s, in_qsize 1, out_qsize 0
# INFO - 15:29:35: EPOCH 8 - PROGRESS: at 69.05% examples, 67181 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:36: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:36: EPOCH - 8 : training on 523700 raw words (199266 effective words) took 2.9s, 67883 effective words/s
# INFO - 15:29:37: EPOCH 9 - PROGRESS: at 33.37% examples, 66050 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:38: EPOCH 9 - PROGRESS: at 69.05% examples, 66842 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:39: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:39: EPOCH - 9 : training on 523700 raw words (199201 effective words) took 2.9s, 68269 effective words/s
# INFO - 15:29:40: EPOCH 10 - PROGRESS: at 33.37% examples, 66843 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:41: EPOCH 10 - PROGRESS: at 65.21% examples, 63797 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:42: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:42: EPOCH - 10 : training on 523700 raw words (199075 effective words) took 3.0s, 66196 effective words/s
# INFO - 15:29:43: EPOCH 11 - PROGRESS: at 33.37% examples, 65653 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:44: EPOCH 11 - PROGRESS: at 70.95% examples, 67568 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:45: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:45: EPOCH - 11 : training on 523700 raw words (199385 effective words) took 2.9s, 68189 effective words/s
# INFO - 15:29:46: EPOCH 12 - PROGRESS: at 33.37% examples, 65557 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:47: EPOCH 12 - PROGRESS: at 70.95% examples, 67582 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:48: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:48: EPOCH - 12 : training on 523700 raw words (198819 effective words) took 2.9s, 67955 effective words/s
# INFO - 15:29:49: EPOCH 13 - PROGRESS: at 29.42% examples, 60227 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:50: EPOCH 13 - PROGRESS: at 65.21% examples, 63538 words/s, in_qsize 1, out_qsize 0
# INFO - 15:29:51: EPOCH 13 - PROGRESS: at 100.00% examples, 65520 words/s, in_qsize 0, out_qsize 1
# INFO - 15:29:51: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:51: EPOCH - 13 : training on 523700 raw words (199107 effective words) took 3.0s, 65466 effective words/s
# INFO - 15:29:52: EPOCH 14 - PROGRESS: at 31.39% examples, 63461 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:53: EPOCH 14 - PROGRESS: at 67.17% examples, 65040 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:54: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:54: EPOCH - 14 : training on 523700 raw words (199018 effective words) took 3.0s, 66363 effective words/s
# INFO - 15:29:55: EPOCH 15 - PROGRESS: at 33.37% examples, 65487 words/s, in_qsize 0, out_qsize 0
# INFO - 15:29:56: EPOCH 15 - PROGRESS: at 69.05% examples, 66059 words/s, in_qsize 1, out_qsize 0
# INFO - 15:29:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:29:57: EPOCH - 15 : training on 523700 raw words (199635 effective words) took 3.1s, 64972 effective words/s
# INFO - 15:29:58: EPOCH 16 - PROGRESS: at 33.37% examples, 65752 words/s, in_qsize 1, out_qsize 0
# INFO - 15:29:59: EPOCH 16 - PROGRESS: at 69.05% examples, 66429 words/s, in_qsize 1, out_qsize 0
# INFO - 15:30:00: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:00: EPOCH - 16 : training on 523700 raw words (199205 effective words) took 3.0s, 67427 effective words/s
# INFO - 15:30:01: EPOCH 17 - PROGRESS: at 33.37% examples, 64686 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:02: EPOCH 17 - PROGRESS: at 69.05% examples, 66269 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:03: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:03: EPOCH - 17 : training on 523700 raw words (199196 effective words) took 2.9s, 67873 effective words/s
# INFO - 15:30:04: EPOCH 18 - PROGRESS: at 33.37% examples, 65856 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:05: EPOCH 18 - PROGRESS: at 69.05% examples, 66817 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:06: EPOCH - 18 : training on 523700 raw words (199097 effective words) took 3.0s, 65829 effective words/s
# INFO - 15:30:07: EPOCH 19 - PROGRESS: at 33.37% examples, 66862 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:08: EPOCH 19 - PROGRESS: at 69.05% examples, 67698 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:09: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:09: EPOCH - 19 : training on 523700 raw words (199697 effective words) took 2.9s, 68576 effective words/s
# INFO - 15:30:10: EPOCH 20 - PROGRESS: at 33.37% examples, 65667 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:11: EPOCH 20 - PROGRESS: at 70.95% examples, 66889 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:12: EPOCH - 20 : training on 523700 raw words (199491 effective words) took 2.9s, 68260 effective words/s
# INFO - 15:30:13: EPOCH 21 - PROGRESS: at 33.37% examples, 66532 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:14: EPOCH 21 - PROGRESS: at 69.05% examples, 66857 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:15: EPOCH - 21 : training on 523700 raw words (198582 effective words) took 3.0s, 65717 effective words/s
# INFO - 15:30:16: EPOCH 22 - PROGRESS: at 33.37% examples, 65036 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:17: EPOCH 22 - PROGRESS: at 69.05% examples, 66387 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:18: EPOCH - 22 : training on 523700 raw words (199255 effective words) took 3.0s, 67329 effective words/s
# INFO - 15:30:19: EPOCH 23 - PROGRESS: at 33.37% examples, 64909 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:20: EPOCH 23 - PROGRESS: at 69.05% examples, 66668 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:20: EPOCH - 23 : training on 523700 raw words (199012 effective words) took 2.9s, 67777 effective words/s
# INFO - 15:30:22: EPOCH 24 - PROGRESS: at 33.37% examples, 65812 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:23: EPOCH 24 - PROGRESS: at 67.17% examples, 63749 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:24: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:24: EPOCH - 24 : training on 523700 raw words (198827 effective words) took 3.0s, 65849 effective words/s
# INFO - 15:30:25: EPOCH 25 - PROGRESS: at 33.37% examples, 66234 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:26: EPOCH 25 - PROGRESS: at 69.05% examples, 66508 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:26: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:26: EPOCH - 25 : training on 523700 raw words (199315 effective words) took 2.9s, 67715 effective words/s
# INFO - 15:30:28: EPOCH 26 - PROGRESS: at 33.37% examples, 65257 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:29: EPOCH 26 - PROGRESS: at 70.95% examples, 67409 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:29: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:29: EPOCH - 26 : training on 523700 raw words (199170 effective words) took 2.9s, 68130 effective words/s
# INFO - 15:30:30: EPOCH 27 - PROGRESS: at 29.42% examples, 60177 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:31: EPOCH 27 - PROGRESS: at 65.21% examples, 63666 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:32: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:32: EPOCH - 27 : training on 523700 raw words (199503 effective words) took 3.0s, 65885 effective words/s
# INFO - 15:30:33: EPOCH 28 - PROGRESS: at 33.37% examples, 66898 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:34: EPOCH 28 - PROGRESS: at 69.05% examples, 67378 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:35: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:35: EPOCH - 28 : training on 523700 raw words (199304 effective words) took 2.9s, 68354 effective words/s
# INFO - 15:30:36: EPOCH 29 - PROGRESS: at 33.37% examples, 66220 words/s, in_qsize 1, out_qsize 0
# INFO - 15:30:37: EPOCH 29 - PROGRESS: at 69.05% examples, 66861 words/s, in_qsize 1, out_qsize 0
# INFO - 15:30:38: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:38: EPOCH - 29 : training on 523700 raw words (199329 effective words) took 2.9s, 67996 effective words/s
# INFO - 15:30:39: EPOCH 30 - PROGRESS: at 29.42% examples, 60162 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:40: EPOCH 30 - PROGRESS: at 65.21% examples, 63052 words/s, in_qsize 0, out_qsize 0
# INFO - 15:30:41: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:30:41: EPOCH - 30 : training on 523700 raw words (198902 effective words) took 3.0s, 65691 effective words/s
# INFO - 15:30:41: training on a 15711000 raw words (5975803 effective words) took 89.3s, 66890 effective words/s
# Time to train the model: 1.49 mins

# %%
w2v_model.init_sims(replace=True)
# Out:
# INFO - 13:50:06: precomputing L2-norms of word weight vectors

# %% [markdown]
# # Explorando o modelo
# ## Mais semelhante a:
#
# Aqui, pediremos ao nosso modelo para encontrar a palavra mais semelhante a alguns dos personagens mais icônicos dos Simpsons!

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/0/02/Homer_Simpson_2006.png/revision/latest?cb=20091207194310" alt="drawing" width="130"/>
#
# Vamos ver o que temos para o personagem principal do show:

# %%
w2v_model.wv.most_similar(positive=["homer"])
# Out:
# INFO - 15:34:03: precomputing L2-norms of word weight vectors
# [('bongo', 0.7775855660438538),
#  ('marge', 0.7622817754745483),
#  ('wife', 0.7618545293807983),
#  ('rude', 0.7597092986106873),
#  ('snuggle', 0.7561238408088684),
#  ('gee', 0.746586799621582),
#  ('crummy', 0.7406914234161377),
#  ('attract', 0.7369040250778198),
#  ('sorry', 0.7336699962615967),
#  ('eliza', 0.7291662096977234)]

# %% [markdown]
# _Uma pequena precisão aqui: _ <br>
# O conjunto de dados são as linhas de diálogo dos Simpsons; portanto, quando olhamos para as palavras mais semelhantes de "homer", ** não ** necessariamente obtemos seus familiares, traços de personalidade ou mesmo suas palavras mais citáveis. Não, entendemos o que outros personagens (como Homer não costuma se referir a si mesmo na 3ª pessoa) disseram junto com "homer", como ele se sente ou parece ("deprimido"), onde ele está ("rede"), ou com quem ("marge").
#
# Vamos ver o que o bigrama "homer_simpson" nos dá por comparação:

# %%
w2v_model.wv.most_similar(positive=["homer_simpson"])
# Out:
# [('congratulation', 0.7728228569030762),
#  ('recent', 0.7618907690048218),
#  ('governor', 0.7498410940170288),
#  ('council', 0.7488455772399902),
#  ('waylon', 0.747048020362854),
#  ('erotic', 0.7465346455574036),
#  ('easily', 0.7438462972640991),
#  ('defeat', 0.7413300275802612),
#  ('fellow', 0.733111560344696),
#  ('hutz', 0.7310960292816162)]

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/0/0b/Marge_Simpson.png/revision/latest?cb=20180626055729" alt="drawing" width="150"/>
# E a Marge agora?

# %%
w2v_model.wv.most_similar(positive=["marge"])
# Out:
# [('convince', 0.7846357226371765),
#  ('rude', 0.7754802107810974),
#  ('sure', 0.7670221328735352),
#  ('attract', 0.7660658359527588),
#  ('arrange', 0.7653926610946655),
#  ('homer', 0.7622817754745483),
#  ('grownup', 0.7614103555679321),
#  ('becky', 0.7611736059188843),
#  ('darling', 0.7604072093963623),
#  ('sorry', 0.7592805624008179)]

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/6/65/Bart_Simpson.png/revision/latest?cb=20180319061933" alt="drawing" width="100"/>
#
# Lagora o bart:

# %%
w2v_model.wv.most_similar(positive=["bart"])
# Out:
# [('lisa', 0.847785472869873),
#  ('homework', 0.7990211248397827),
#  ('upset', 0.7891772985458374),
#  ('mom', 0.785849928855896),
#  ('convince', 0.7823788523674011),
#  ('surprised', 0.7813987731933594),
#  ('mom_dad', 0.7658380270004272),
#  ('strangle', 0.7577166557312012),
#  ('substitute', 0.7522090673446655),
#  ('typical', 0.7496157288551331)]

# %% [markdown]
# Parece que está fazendo sentido!
#
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/9/9d/Groundskeeper_Willie.png/revision/latest?cb=20130424154035" alt="drawing" width="150"/>
#
# e agora o escoces willy

# %% [markdown]
# ## Similaridades:
# Aqui, veremos como duas palavras são semelhantes:

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/6/6c/MaggieSimpson.PNG/revision/latest?cb=20180314210204" alt="drawing" width="100"/>

# %%
w2v_model.wv.similarity('maggie', 'baby')
# Out:
# 0.7106367

# %% [markdown]
# Maggie is indeed the most renown baby in the Simpsons!

# %%
w2v_model.wv.similarity('bart', 'nelson')
# Out:
# 0.6688139

# %% [markdown]
# Bart e Nelson, embora amigos, não sejam tão próximos, faz sentido!
#
# ## Odd-One-Out:
#
# Aqui, pedimos ao nosso modelo que nos dê a palavra que não pertence à lista!
#
# Entre Jimbo, Milhouse e Kearney, quem é aquele que  é um valentão?

# %%
w2v_model.wv.doesnt_match(['jimbo', 'milhouse', 'kearney'])
# Out:
# WARNING - 13:50:07: vectors for words {'kearney'} are not present in the model, ignoring these words
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'jimbo'

# %%
w2v_model.wv.doesnt_match(["nelson", "bart", "milhouse"])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'nelson'

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/4/40/Picture0003.jpg/revision/latest?cb=20110623042517" alt="drawing" width="200"/>
#
# Por último, mas não menos importante, como é a relação entre Homer e suas duas cunhadas?

# %%
w2v_model.wv.doesnt_match(['homer', 'patty', 'selma'])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'homer'

# %% [markdown]
# Droga, eles realmente não gostam de você Homer!
#
# ## Diferença de analogia:
# Qual palavra é para mulher como homer é para marge?

# %%
w2v_model.wv.most_similar(positive=["woman", "homer"], negative=["marge"], topn=3)
# Out:
# [('admire', 0.6785337328910828),
#  ('wife', 0.6342260241508484),
#  ('ought', 0.6182737350463867)]

# %%
w2v_model.wv.most_similar(positive=["woman", "bart"], negative=["man"], topn=3)
# Out:
# [('parent', 0.744362473487854),
#  ('lisa', 0.7373144626617432),
#  ('pregnant', 0.7276972532272339)]

# %% [markdown]
# Lisa is Bart's sister, her male counterpart!
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/5/57/Lisa_Simpson2.png/revision/latest?cb=20180319000458" alt="drawing" width="100"/>

# %% [markdown]
# ### Visualizações t-SNE:
# t-SNE é um algoritmo de redução de dimensionalidade não linear que tenta representar dados dimensionais elevados e as relações subjacentes entre vetores em um espaço de dimensão inferior. <br>
# Aqui está um bom tutorial sobre isso: https://medium.com/@luckylwk/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b

# %%
# !pip install scikit-learn==0.19.0
# Out:
# Requirement already satisfied: scikit-learn==0.19.0 in /usr/local/lib/python3.6/dist-packages (0.19.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
import seaborn as sns
sns.set_style("darkgrid")
import sklearn
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
sklearn.__version__
# Out:
# '0.19.0'

# %% [markdown]
# Nosso objetivo nesta seção é plotar nossos vetores de 300 dimensões em gráficos bidimensionais e ver se podemos localizar padrões interessantes. <br>
# Para isso, usaremos a implementação t-SNE do scikit-learn.
#
# Para tornar as visualizações mais relevantes, examinaremos as relações entre uma palavra de consulta (em <font color = 'red'> ** vermelho ** </font>), suas palavras mais semelhantes no modelo (em <cor da fonte = "blue"> ** blue ** </font>) e outras palavras do vocabulário (em <font color = 'green'> ** verde ** </font>).

# %%
def tsnescatterplot(model, word, list_names):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    
    # adds the vector for each of the closest words to the array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    reduc = PCA(n_components=50).fit_transform(arrays)
    
    # Finds t-SNE coordinates for 2 dimensions
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %% [markdown]
# ## 10 palavras mais semelhantes vs. 8 palavras aleatórias:
# Vamos comparar onde a representação vetorial de Homer, suas 10 palavras mais semelhantes do modelo, bem como 8 palavras aleatórias, se encontram em um gráfico 2D:

# %%
tsnescatterplot(w2v_model, 'homer', ['dog', 'bird', 'ah', 'maude', 'bob', 'mel', 'apu', 'duff'])

# %% [markdown]
# Curiosamente, as 10 palavras mais semelhantes a Homer acabam em torno dele, assim como Apu e (show à parte) Bob, dois personagens recorrentes.
#
# ## 10 palavras mais semelhantes vs. 10 mais diferentes
#
# Desta vez, vamos comparar onde a representação vetorial de Maggie e suas 10 palavras mais semelhantes do modelo se compara à representação vetorial das 10 palavras mais diferentes de Maggie:

# %%
tsnescatterplot(w2v_model, 'maggie', [i[0] for i in w2v_model.wv.most_similar(negative=["maggie"])])

# %% [markdown]
# Arrumado! Maggie e suas palavras mais semelhantes formam um grupo distinto das palavras mais diferentes, é um enredo realmente encorajador!
